# %% [markdown]
# # LSTM Bubble Early-Warning Pipeline
#
# Final notebook for the LSTM-based early warning model in our cryptocurrency bubble project.
#
# ## Objective
# Predict the next-period bubble state using engineered market, sentiment, and macro features.
#
# ## Scope
# - **Main target:** `gsadf_map_90_lead`
# - **Classes:** Not Bubble, Bubble Creation, Bubble Collapse
# - **Coins:** ADA, BNB, BTC, DOGE, ETH, SOL
#
# ## Notes
# - This final version uses `gsadf_map_90_lead` as the main benchmark target.
# - The notebook keeps the full 3-class evaluation for all selected coins.
# - **ADA** and **DOGE** are excluded only from the collapse-focused benchmark view when out-of-sample collapse labels are too sparse under chronological evaluation.

# %% [markdown]
# ## 1. Imports

# %%
import os
import random
import copy
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import (
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    classification_report,
)

sns.set_theme(style="whitegrid")
plt.rcParams["figure.dpi"] = 130

# %% [markdown]
# ## 2. Configuration
#
# This section defines:
# - dataset paths,
# - primary and secondary target labels,
# - coins used in the experiment,
# - feature set,
# - manual train/validation/test splits,
# - training defaults, and
# - collapse-focused weighting / threshold settings.

# %%
# Paths
DATA_CANDIDATES = [
    "df_features_with_label_standardised.csv",
    "data/df_features_with_label_standardised.csv",
    "/mnt/data/df_features_with_label_standardised.csv",
]

OUTPUT_DIR = Path("lstm_outputs_benchmark_90_main")
OUTPUT_DIR.mkdir(exist_ok=True)

# Experiment setup
TARGET_COL = "gsadf_map_90_lead"              # main benchmark label

CLASS_NAMES = ["Not Bubble", "Bubble Creation", "Bubble Collapse"]
LABELS = [0, 1, 2]

COINS_TO_RUN = ["ADA", "BNB", "BTC", "DOGE", "ETH", "SOL"]
COLLAPSE_BENCHMARK_EXCLUDE = ["ADA", "DOGE"]
COLLAPSE_BENCHMARK_COINS = [c for c in COINS_TO_RUN if c not in COLLAPSE_BENCHMARK_EXCLUDE]

# Feature selection
FEATURE_MODE = "manual"

MANUAL_FEATURES = [
    # 1) Price / regime anchor
    "close",
    "ma_30",
    "ma_60",
    "ma_ratio_7_30",
    "ma_ratio_30_60",
    "zscore_30",
    "zscore_60",
    "price_position_60",

    # 2) Momentum / build-up
    "ret_7d",
    "ret_14d",
    "ret_30d",
    "rsi_14",
    "rsi_30",
    "roc_14",
    "roc_30",

    # 3) Volatility / stress
    "atr_14",
    "atr_30",
    "realized_vol_30",
    "volume_ratio_7",
    "volume_std_30",
    "price_volume_corr_30",

    # 4) Search / attention
    "own_trend_ma_14",
    "own_trend_ma_30",
    "own_trend_std_30",
    "crypto_crash_zscore",
    "altcoin_season_zscore",

    # 5) Sentiment level + reversal
    "fear_greed",
    "fear_greed_ma_14",
    "fear_greed_ma_30",
    "fear_greed_change_1d",
    "fear_greed_change_7d",
    "fear_greed_lag_7",
    "extreme_greed",
    "fear",
    "greed",

    # 6) Macro risk regime
    "vix",
    "vix_change_1d",
    "real_rate_10y",
    "risk_off_signal",

    # 7) Short lagged reversal
    "ret_7d_lag_1",
    "rsi_14_lag_1",
    "ret_1d_lag_3",
    "ret_7d_lag_3",
]

LOOKBACK_CANDIDATES_BY_COIN = {
    "ADA": [14, 21],
    "BNB": [14, 21, 30],
    "BTC": [14, 21, 30],
    "DOGE": [14, 21],
    "ETH": [14, 21, 30],
    "SOL": [7, 14, 21],
}
DEFAULT_LOOKBACK_CANDIDATES = [14, 21, 30]

# Manual splits chosen after checking yearly/monthly collapse timing
MANUAL_SPLITS_BY_TARGET = {
    "gsadf_map_95_lead": {
        "ADA":  {"val_start": "2021-06-01", "test_start": "2021-10-01"},
        "BNB":  {"val_start": "2021-03-01", "test_start": "2022-01-01"},
        "BTC":  {"val_start": "2021-03-01", "test_start": "2022-01-01"},
        "DOGE": {"val_start": "2021-06-01", "test_start": "2021-09-01"},
        "ETH":  {"val_start": "2021-06-01", "test_start": "2022-01-01"},
        "SOL":  {"val_start": "2021-10-01", "test_start": "2022-06-01"},
    },
    "gsadf_map_90_lead": {
        "ADA":  {"val_start": "2021-06-01", "test_start": "2021-10-01"},
        "BNB":  {"val_start": "2021-03-01", "test_start": "2022-01-01"},
        "BTC":  {"val_start": "2021-03-01", "test_start": "2022-01-01"},
        "DOGE": {"val_start": "2021-06-01", "test_start": "2021-09-01"},
        "ETH":  {"val_start": "2021-06-01", "test_start": "2022-01-01"},
        "SOL":  {"val_start": "2021-10-01", "test_start": "2022-06-01"},
    },
}

# Training defaults
BATCH_SIZE = 32
EPOCHS = 15
PATIENCE = 4
LEARNING_RATE = 5e-4
WEIGHT_DECAY = 1e-4

HIDDEN_SIZE = 32
NUM_LAYERS = 1
DROPOUT = 0.30
DENSE_SIZE = 16

# Coin-specific class weights
USE_CLASS_WEIGHTS = True
CLASS_WEIGHT_MODE = "manual"

MANUAL_CLASS_WEIGHT_BY_COIN = {
    "ADA":  {0: 1.0, 1: 1.2, 2: 1.6},
    "BNB":  {0: 1.0, 1: 1.2, 2: 6.8},
    "BTC":  {0: 1.0, 1: 1.2, 2: 1.6},
    "DOGE": {0: 1.0, 1: 1.2, 2: 1.6},
    "ETH":  {0: 1.0, 1: 1.3, 2: 6.8},
    "SOL":  {0: 1.0, 1: 1.2, 2: 1.6},
}
DEFAULT_MANUAL_CLASS_WEIGHT = {0: 1.0, 1: 1.2, 2: 1.6}

# Selection / early stopping
COLLAPSE_CLASS = 2
MIN_CLASS_COUNT_WARNING = 5
NO_COLLAPSE_VAL_PENALTY = 0.05
EVENT_SELECTION_WEIGHT_CREATION = 0.55
EVENT_SELECTION_WEIGHT_COLLAPSE = 0.45

# Collapse-aware post-processing / sampling
USE_COLLAPSE_THRESHOLD = True
COLLAPSE_THRESHOLD_GRID_BY_COIN = {
    "BTC": [0.15, 0.20, 0.25, 0.30, 0.35, 0.40],
    "BNB": [0.15, 0.20, 0.25, 0.30, 0.35, 0.40],
    "ETH": [0.10, 0.15, 0.20, 0.25, 0.30, 0.35],
    "SOL": [0.10, 0.15, 0.20, 0.25, 0.30],
    "ADA": [0.20, 0.25, 0.30, 0.35],
    "DOGE": [0.20, 0.25, 0.30, 0.35],
}
DEFAULT_COLLAPSE_THRESHOLD_GRID = [0.15, 0.20, 0.25, 0.30, 0.35]
DEFAULT_FIXED_COLLAPSE_THRESHOLD = 0.25

USE_COLLAPSE_OVERSAMPLING = True
COLLAPSE_OVERSAMPLE_BY_COIN = {
    "BTC": 4,
    "BNB": 5,
    "ETH": 4,
    "SOL": 3,
    "ADA": 1,
    "DOGE": 1,
}
DEFAULT_COLLAPSE_OVERSAMPLE = 1

# Infrastructure
SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)
print("Main target:", TARGET_COL)
print("Secondary target:", TARGET_COL)
print("Collapse benchmark coins:", COLLAPSE_BENCHMARK_COINS)
# Out:
# Using device: cpu
# Main target: gsadf_map_90_lead
# Secondary target: gsadf_map_90_lead
# Collapse benchmark coins: ['BNB', 'BTC', 'ETH', 'SOL']

# %% [markdown]
# ## 3. Utility Functions
#
# Helper functions for:
# - reproducibility,
# - file resolution,
# - directory creation.

# %%
def set_seed(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(SEED)


def resolve_data_path(candidates):
    for p in candidates:
        if Path(p).exists():
            return Path(p)
    raise FileNotFoundError(
        "Could not find dataset. Checked:\n" + "\n".join(candidates)
    )


def ensure_dir(path: Path):
    path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 4. Load Data
#
# Load the engineered feature dataset and inspect the basic class distribution for the main target.

# %%
data_path = resolve_data_path(DATA_CANDIDATES)

df = pd.read_csv(data_path, parse_dates=["date"])
df = df.sort_values(["symbol", "date"]).reset_index(drop=True)

print(f"Loaded: {data_path}")
print(f"Shape : {df.shape}")
print(f"Date range: {df['date'].min().date()} -> {df['date'].max().date()}")
print(f"Coins: {sorted(df['symbol'].unique().tolist())}")

print(f"\nClass distribution (target = {TARGET_COL}):")
display(df.groupby("symbol")[TARGET_COL].value_counts().unstack(fill_value=0))
# Out:
# Loaded: df_features_with_label_standardised.csv
# Shape : (13359, 146)
# Date range: 2018-05-01 -> 2024-12-31
# Coins: ['ADA', 'BNB', 'BTC', 'DOGE', 'ETH', 'SOL']
#
# Class distribution (target = gsadf_map_90_lead):
# gsadf_map_90_lead     0    1    2
# symbol
# ADA                1942  337  158
# BNB                1900  347  190
# BTC                1903  412  122
# DOGE               1632  259  116
# ETH                1918  356  163
# SOL                1137  290  177

# %% [markdown]
# ## 5. Label Timing Check
#
# Review label timing by coin to support:
# - chronological split design,
# - interpretation of sparse collapse cases,
# - optional robustness testing.

# %%
def label_distribution_by_year(df_in: pd.DataFrame, target_col: str):
    out = df_in[["symbol", "date", target_col]].copy()
    out["year"] = out["date"].dt.year
    return (
        out.groupby(["symbol", "year"])[target_col]
        .value_counts()
        .unstack(fill_value=0)
        .rename(columns={0: "not_bubble", 1: "creation", 2: "collapse"})
        .reset_index()
    )

yearly_label_df = label_distribution_by_year(df, TARGET_COL)
display(yearly_label_df)

print("Target used for the benchmark:", TARGET_COL)
print("Coins excluded from collapse benchmark:", COLLAPSE_BENCHMARK_EXCLUDE)
# Out:
# gsadf_map_90_lead symbol  year  not_bubble  creation  collapse
# 0                    ADA  2018         245         0         0
# 1                    ADA  2019         365         0         0
# 2                    ADA  2020         302        64         0
# 3                    ADA  2021          28       190       147
# 4                    ADA  2022         353         1        11
# 5                    ADA  2023         330        35         0
# 6                    ADA  2024         319        47         0
# 7                    BNB  2018         245         0         0
# 8                    BNB  2019         343         2        20
# 9                    BNB  2020         352        14         0
# 10                   BNB  2021          30       222       113
# 11                   BNB  2022         331         0        34
# 12                   BNB  2023         353         7         5
# 13                   BNB  2024         246       102        18
# 14                   BTC  2018         245         0         0
# 15                   BTC  2019         333        15        17
# 16                   BTC  2020         304        62         0
# 17                   BTC  2021         139       171        55
# 18                   BTC  2022         338         0        27
# 19                   BTC  2023         336        29         0
# 20                   BTC  2024         208       135        23
# 21                  DOGE  2019         180         0         0
# 22                  DOGE  2020         361         5         0
# 23                  DOGE  2021         101       162       102
# 24                  DOGE  2022         347         5        13
# 25                  DOGE  2023         354        11         0
# 26                  DOGE  2024         289        76         1
# 27                   ETH  2018         245         0         0
# 28                   ETH  2019         365         0         0
# 29                   ETH  2020         314        52         0
# 30                   ETH  2021           4       250       111
# 31                   ETH  2022         318         0        47
# 32                   ETH  2023         360         5         0
# 33                   ETH  2024         312        49         5
# 34                   SOL  2020         143         0         0
# 35                   SOL  2021         216       110        39
# 36                   SOL  2022         262         2       101
# 37                   SOL  2023         294        67         4
# 38                   SOL  2024         222       111        33
# Target used for the benchmark: gsadf_map_90_lead
# Coins excluded from collapse benchmark: ['ADA', 'DOGE']

# %% [markdown]
# ## 6. Feature Setup
#
# Select the final numeric feature set used for sequence modelling.

# %%
NON_FEATURE_COLS = [
    "date",
    "symbol",
    "gsadf_map_95",
    "gsadf_map_90",
    "gsadf_map_95_lead",
    "gsadf_map_90_lead",
]

def get_feature_columns(df: pd.DataFrame, feature_mode: str = "all", manual_features=None):
    numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    numeric_cols = [c for c in numeric_cols if c not in NON_FEATURE_COLS]

    if feature_mode == "all":
        feature_cols = numeric_cols
    elif feature_mode == "manual":
        if not manual_features:
            raise ValueError("FEATURE_MODE='manual' but MANUAL_FEATURES is empty.")
        missing = [c for c in manual_features if c not in df.columns]
        if missing:
            print("Warning: these manual features were not found and will be skipped:")
            print(missing)
        feature_cols = [c for c in manual_features if c in numeric_cols]
    else:
        raise ValueError("feature_mode must be 'all' or 'manual'")

    if len(feature_cols) == 0:
        raise ValueError("No usable feature columns selected.")

    return feature_cols

FEATURE_COLS = get_feature_columns(df, feature_mode=FEATURE_MODE, manual_features=MANUAL_FEATURES)
print(f"Feature mode: {FEATURE_MODE}")
print(f"Number of features: {len(FEATURE_COLS)}")
print(FEATURE_COLS[:20], "..." if len(FEATURE_COLS) > 20 else "")
# Out:
# Warning: these manual features were not found and will be skipped:
# ['risk_off_signal']
# Feature mode: manual
# Number of features: 42
# ['close', 'ma_30', 'ma_60', 'ma_ratio_7_30', 'ma_ratio_30_60', 'zscore_30', 'zscore_60', 'price_position_60', 'ret_7d', 'ret_14d', 'ret_30d', 'rsi_14', 'rsi_30', 'roc_14', 'roc_30', 'atr_14', 'atr_30', 'realized_vol_30', 'volume_ratio_7', 'volume_std_30'] ...

# %% [markdown]
# ## 7. Chronological Split
#
# Create train, validation, and test splits by date for each coin.

# %%
def split_coin_df_by_date(
    coin_df: pd.DataFrame,
    val_start_date: str,
    test_start_date: str,
):
    coin_df = coin_df.sort_values("date").reset_index(drop=True).copy()
    val_start = pd.Timestamp(val_start_date)
    test_start = pd.Timestamp(test_start_date)

    train_df = coin_df[coin_df["date"] < val_start].copy()
    val_df = coin_df[(coin_df["date"] >= val_start) & (coin_df["date"] < test_start)].copy()
    test_df = coin_df[coin_df["date"] >= test_start].copy()

    split_info = {
        "train_start": str(train_df["date"].min().date()) if len(train_df) else None,
        "train_end": str(train_df["date"].max().date()) if len(train_df) else None,
        "val_start": str(val_df["date"].min().date()) if len(val_df) else None,
        "val_end": str(val_df["date"].max().date()) if len(val_df) else None,
        "test_start": str(test_df["date"].min().date()) if len(test_df) else None,
        "test_end": str(test_df["date"].max().date()) if len(test_df) else None,
    }
    return train_df, val_df, test_df, split_info


def split_coin_df_manual_or_default(
    coin: str,
    coin_df: pd.DataFrame,
    target_col: str,
):
    manual_cfg = MANUAL_SPLITS_BY_TARGET.get(target_col, {}).get(coin)

    if manual_cfg is None:
        # conservative fallback only if a manual split is missing
        train_df, val_df, test_df, split_info = split_coin_df_by_date(
            coin_df=coin_df,
            val_start_date="2023-01-01",
            test_start_date="2024-01-01",
        )
        split_info.update({
            "split_strategy": "default_fallback",
            "target_col": target_col,
            "coin": coin,
        })
        return train_df, val_df, test_df, split_info

    train_df, val_df, test_df, split_info = split_coin_df_by_date(
        coin_df=coin_df,
        val_start_date=manual_cfg["val_start"],
        test_start_date=manual_cfg["test_start"],
    )

    split_info.update({
        "split_strategy": "manual_data_aware",
        "coin": coin,
        "target_col": target_col,
        "candidate_val_start": manual_cfg["val_start"],
        "candidate_test_start": manual_cfg["test_start"],
        "raw_train_counts": coin_df[coin_df["date"] < pd.Timestamp(manual_cfg["val_start"])][target_col].value_counts().sort_index().to_dict(),
        "raw_val_counts": coin_df[(coin_df["date"] >= pd.Timestamp(manual_cfg["val_start"])) & (coin_df["date"] < pd.Timestamp(manual_cfg["test_start"]))][target_col].value_counts().sort_index().to_dict(),
        "raw_test_counts": coin_df[coin_df["date"] >= pd.Timestamp(manual_cfg["test_start"])][target_col].value_counts().sort_index().to_dict(),
        "collapse_benchmark_eligible": coin not in COLLAPSE_BENCHMARK_EXCLUDE,
    })
    return train_df, val_df, test_df, split_info


def get_lookbacks_for_coin(coin: str):
    return LOOKBACK_CANDIDATES_BY_COIN.get(coin, DEFAULT_LOOKBACK_CANDIDATES)


def get_class_weight_for_coin(coin: str):
    return MANUAL_CLASS_WEIGHT_BY_COIN.get(coin, DEFAULT_MANUAL_CLASS_WEIGHT)

# %% [markdown]
# ## 8. Sequence Creation
#
# Convert tabular features into rolling LSTM sequences based on the selected lookback window.

# %%
def create_sequences(coin_df: pd.DataFrame, feature_cols, target_col: str, lookback: int):
    coin_df = coin_df.sort_values("date").reset_index(drop=True).copy()

    X_raw = coin_df[feature_cols].to_numpy(dtype=np.float32)
    y_raw = coin_df[target_col].to_numpy(dtype=np.int64)
    dates = coin_df["date"].to_numpy()

    X_seq, y_seq, end_dates = [], [], []
    for end_idx in range(lookback - 1, len(coin_df)):
        start_idx = end_idx - lookback + 1
        X_seq.append(X_raw[start_idx:end_idx + 1])
        y_seq.append(y_raw[end_idx])
        end_dates.append(dates[end_idx])

    if len(X_seq) == 0:
        return (
            np.empty((0, lookback, len(feature_cols)), dtype=np.float32),
            np.empty((0,), dtype=np.int64),
            np.array([], dtype='datetime64[ns]'),
        )

    return np.stack(X_seq), np.array(y_seq, dtype=np.int64), np.array(end_dates)

# %% [markdown]
# ## 9. Dataset and DataLoader
#
# Wrap the sequence arrays into PyTorch datasets and loaders.

# %%
class SequenceDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


def make_loader(X, y, batch_size=32, shuffle=False):
    ds = SequenceDataset(X, y)
    return DataLoader(ds, batch_size=batch_size, shuffle=shuffle)

# %% [markdown]
# ## 10. Model
#
# LSTM classifier for 3-class bubble-state prediction.

# %%
class LSTMClassifier(nn.Module):
    def __init__(
        self,
        input_size: int,
        hidden_size: int = 32,
        num_layers: int = 1,
        dropout: float = 0.3,
        dense_size: int = 16,
        num_classes: int = 3,
    ):
        super().__init__()
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=dropout if num_layers > 1 else 0.0,
        )
        self.dropout = nn.Dropout(dropout)
        self.fc1 = nn.Linear(hidden_size, dense_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(dense_size, num_classes)

    def forward(self, x):
        out, _ = self.lstm(x)
        last_hidden = out[:, -1, :]
        x = self.dropout(last_hidden)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ## 11. Training Helpers
#
# Utilities for:
# - class weighting,
# - threshold tuning,
# - early stopping,
# - evaluation metrics.

# %%
def compute_auto_class_weights(y, num_classes=3):
    counts = np.bincount(y, minlength=num_classes)
    weights = np.zeros(num_classes, dtype=np.float32)
    nonzero = counts > 0
    weights[nonzero] = len(y) / (num_classes * counts[nonzero])
    return torch.tensor(weights, dtype=torch.float32)


def get_class_weights(y_train, mode="manual", manual_weight=None, num_classes=3):
    if mode == "manual":
        if manual_weight is None:
            raise ValueError("manual_weight is required when CLASS_WEIGHT_MODE='manual'")
        weight_list = [manual_weight.get(i, 1.0) for i in range(num_classes)]
        return torch.tensor(weight_list, dtype=torch.float32)
    elif mode == "auto":
        return compute_auto_class_weights(y_train, num_classes=num_classes)
    else:
        raise ValueError("mode must be 'manual' or 'auto'")


def get_collapse_threshold_grid_for_coin(coin: str):
    return COLLAPSE_THRESHOLD_GRID_BY_COIN.get(coin, DEFAULT_COLLAPSE_THRESHOLD_GRID)


def get_collapse_oversample_multiplier_for_coin(coin: str):
    return COLLAPSE_OVERSAMPLE_BY_COIN.get(coin, DEFAULT_COLLAPSE_OVERSAMPLE)


def oversample_target_class(X, y, target_class=2, multiplier=1, seed=42):
    if multiplier <= 1:
        return X, y
    idx = np.where(y == target_class)[0]
    if len(idx) == 0:
        return X, y

    rng = np.random.default_rng(seed)
    extra_idx = rng.choice(idx, size=len(idx) * (multiplier - 1), replace=True)
    X_extra = X[extra_idx]
    y_extra = y[extra_idx]

    X_new = np.concatenate([X, X_extra], axis=0)
    y_new = np.concatenate([y, y_extra], axis=0)

    perm = rng.permutation(len(y_new))
    return X_new[perm], y_new[perm]


def predict_with_collapse_threshold(probs, collapse_threshold=0.25):
    probs = np.asarray(probs)
    if probs.ndim != 2 or probs.shape[1] != 3:
        raise ValueError("Expected probs with shape (n_samples, 3).")

    preds = []
    for p in probs:
        if float(p[2]) >= collapse_threshold:
            preds.append(2)
        else:
            preds.append(int(np.argmax(p[:2])))
    return np.array(preds, dtype=np.int64)


def evaluate_loader(model, loader, criterion, collapse_threshold=None):
    model.eval()
    losses = []
    y_true, all_probs = [], []

    with torch.no_grad():
        for xb, yb in loader:
            xb = xb.to(DEVICE)
            yb = yb.to(DEVICE)
            logits = model(xb)
            loss = criterion(logits, yb)
            probs = torch.softmax(logits, dim=1)

            losses.append(loss.item())
            y_true.extend(yb.cpu().numpy().tolist())
            all_probs.append(probs.cpu().numpy())

    avg_loss = float(np.mean(losses)) if losses else np.nan
    probs_np = np.concatenate(all_probs, axis=0) if all_probs else np.empty((0, 3), dtype=np.float32)
    y_true_np = np.array(y_true, dtype=np.int64)

    if collapse_threshold is None:
        y_pred_np = probs_np.argmax(axis=1) if len(probs_np) else np.empty((0,), dtype=np.int64)
    else:
        y_pred_np = predict_with_collapse_threshold(probs_np, collapse_threshold=collapse_threshold)

    return avg_loss, y_true_np, y_pred_np, probs_np


def tune_collapse_threshold(coin, y_true, probs):
    if len(y_true) == 0:
        return DEFAULT_FIXED_COLLAPSE_THRESHOLD, np.nan, {}

    threshold_grid = get_collapse_threshold_grid_for_coin(coin)
    mode = get_selection_mode_for_coin(coin)
    best_thr = DEFAULT_FIXED_COLLAPSE_THRESHOLD
    best_score = -np.inf
    diag = {}

    for thr in threshold_grid:
        y_pred = predict_with_collapse_threshold(probs, collapse_threshold=thr)
        pc = per_class_metrics(y_true, y_pred)
        score = compute_event_selection_score(
            coin=coin,
            creation_f1=pc[1]["f1"],
            collapse_f1=pc[2]["f1"],
            val_counts=safe_label_counts(y_true),
        )
        diag[thr] = {
            "selection_score": float(score),
            "creation_f1": float(pc[1]["f1"]),
            "collapse_f1": float(pc[2]["f1"]),
            "collapse_recall": float(pc[2]["recall"]),
            "pred_counts": safe_label_counts(y_pred),
        }
        if score > best_score:
            best_score = score
            best_thr = thr

    return float(best_thr), float(best_score), diag


def train_one_epoch(model, loader, criterion, optimizer):
    model.train()
    losses = []
    for xb, yb in loader:
        xb = xb.to(DEVICE)
        yb = yb.to(DEVICE)

        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        losses.append(loss.item())
    return float(np.mean(losses)) if losses else np.nan

# %% [markdown]
# ## 12. Coin-Level Experiment Wrapper
#
# Run the full training and evaluation pipeline for one coin across candidate lookbacks.

# %% [markdown]
# ## 12B. Evaluation Helpers
#
# Helper functions for per-class metrics, label counts, and collapse-focused selection logic.

# %%
from collections import Counter

def safe_label_counts(y, labels=LABELS):
    counter = Counter(np.asarray(y).tolist())
    return {int(lbl): int(counter.get(lbl, 0)) for lbl in labels}

def per_class_metrics(y_true, y_pred, labels=LABELS):
    precision = precision_score(y_true, y_pred, average=None, labels=labels, zero_division=0)
    recall = recall_score(y_true, y_pred, average=None, labels=labels, zero_division=0)
    f1 = f1_score(y_true, y_pred, average=None, labels=labels, zero_division=0)
    return {
        int(lbl): {
            "precision": float(precision[i]),
            "recall": float(recall[i]),
            "f1": float(f1[i]),
        }
        for i, lbl in enumerate(labels)
    }

def get_selection_mode_for_coin(coin: str):
    if coin in COLLAPSE_BENCHMARK_EXCLUDE:
        return "creation_only"
    return "creation_collapse_weighted"

def compute_event_selection_score(coin: str, creation_f1: float, collapse_f1: float, val_counts=None):
    mode = get_selection_mode_for_coin(coin)

    if mode == "creation_only":
        score = float(creation_f1)
    elif mode == "creation_collapse_weighted":
        score = float(
            EVENT_SELECTION_WEIGHT_CREATION * creation_f1
            + EVENT_SELECTION_WEIGHT_COLLAPSE * collapse_f1
        )
        if val_counts is not None and val_counts.get(COLLAPSE_CLASS, 0) == 0:
            score -= NO_COLLAPSE_VAL_PENALTY
    else:
        raise ValueError(f"Unknown selection mode: {mode}")
    return float(score)

def build_candidate_row(
    coin,
    lookback,
    target_col,
    selection_mode,
    y_train,
    y_val,
    y_test,
    y_val_true,
    y_val_pred,
    y_test_true,
    y_test_pred,
    best_epoch_metrics,
):
    val_pc = per_class_metrics(y_val_true, y_val_pred)
    test_pc = per_class_metrics(y_test_true, y_test_pred)

    row = {
        "coin": coin,
        "target_col": target_col,
        "lookback": int(lookback),
        "selection_mode": selection_mode,
        "threshold": float(best_epoch_metrics.get("selected_threshold", DEFAULT_FIXED_COLLAPSE_THRESHOLD)),
        "train_counts": safe_label_counts(y_train),
        "val_counts": safe_label_counts(y_val),
        "test_counts": safe_label_counts(y_test),
        "pred_val_counts": safe_label_counts(y_val_pred),
        "pred_test_counts": safe_label_counts(y_test_pred),
        "val_macro_f1": float(best_epoch_metrics["val_macro_f1"]),
        "val_creation_f1": val_pc[1]["f1"],
        "val_collapse_f1": val_pc[2]["f1"],
        "val_collapse_recall": val_pc[2]["recall"],
        "test_macro_f1": float(best_epoch_metrics["test_macro_f1"]),
        "test_weighted_f1": float(best_epoch_metrics["test_weighted_f1"]),
        "test_creation_f1": test_pc[1]["f1"],
        "test_collapse_f1": test_pc[2]["f1"],
        "test_collapse_recall": test_pc[2]["recall"],
    }
    row["selection_score"] = float(best_epoch_metrics["selection_score"])
    return row

def summarize_candidate_table(candidate_rows):
    if not candidate_rows:
        return pd.DataFrame()

    df = pd.DataFrame(candidate_rows).copy()
    df["train_collapse_n"] = df["train_counts"].apply(lambda d: d.get(COLLAPSE_CLASS, 0))
    df["val_collapse_n"] = df["val_counts"].apply(lambda d: d.get(COLLAPSE_CLASS, 0))
    df["test_collapse_n"] = df["test_counts"].apply(lambda d: d.get(COLLAPSE_CLASS, 0))
    df["pred_test_collapse_n"] = df["pred_test_counts"].apply(lambda d: d.get(COLLAPSE_CLASS, 0))

    display_cols = [
        "coin",
        "target_col",
        "lookback",
        "selection_mode",
        "threshold",
        "selection_score",
        "val_macro_f1",
        "val_creation_f1",
        "val_collapse_f1",
        "val_collapse_recall",
        "test_macro_f1",
        "test_creation_f1",
        "test_collapse_f1",
        "test_collapse_recall",
        "train_collapse_n",
        "val_collapse_n",
        "test_collapse_n",
        "pred_test_collapse_n",
    ]
    return (
        df[display_cols]
        .sort_values(["selection_score", "test_collapse_f1", "test_creation_f1"], ascending=False)
        .reset_index(drop=True)
    )

# %%
def print_split_warnings(coin, y_train, y_val, y_test, collapse_label=2, low_count_threshold=3):
    train_counts = safe_label_counts(y_train)
    val_counts = safe_label_counts(y_val)
    test_counts = safe_label_counts(y_test)

    if train_counts.get(collapse_label, 0) == 0:
        print(f"[WARNING] {coin} | train has zero collapse samples after sequence creation.")
    elif train_counts.get(collapse_label, 0) < low_count_threshold:
        print(f"[WARNING] {coin} | train has very few collapse samples: {train_counts.get(collapse_label, 0)}.")

    if val_counts.get(collapse_label, 0) == 0:
        print(f"[WARNING] {coin} | val has zero collapse samples after sequence creation.")
    elif val_counts.get(collapse_label, 0) < low_count_threshold:
        print(f"[WARNING] {coin} | val has very few collapse samples: {val_counts.get(collapse_label, 0)}.")

    if test_counts.get(collapse_label, 0) == 0:
        print(f"[WARNING] {coin} | test has zero collapse samples after sequence creation.")
    elif test_counts.get(collapse_label, 0) < low_count_threshold:
        print(f"[WARNING] {coin} | test has very few collapse samples: {test_counts.get(collapse_label, 0)}.")

# %%
def benchmark_flag_for_coin(coin: str) -> bool:
    return coin not in COLLAPSE_BENCHMARK_EXCLUDE


def classify_result_status(row: dict) -> str:
    collapse_n = int(row.get("Test Collapse N", 0))
    f1_collapse = float(row.get("F1 Collapse", 0.0))
    f1_creation = float(row.get("F1 Creation", 0.0))

    if collapse_n == 0:
        return "no_test_collapse"
    if collapse_n < 5:
        return "collapse_test_sparse"
    if f1_collapse >= 0.20:
        return "collapse_usable"
    if f1_collapse > 0:
        return "collapse_weak"
    if f1_creation >= 0.40:
        return "creation_only_signal"
    return "poor_signal"

# %% [markdown]
# ### Final Training Setup
#
# This version applies:
# - coin-specific class weights,
# - validation-based collapse threshold tuning,
# - collapse oversampling for benchmark-eligible coins,
# - coin-specific lookback candidates.

# %%
# Run one complete experiment for a single coin

def run_coin_experiment(coin: str, df: pd.DataFrame, feature_cols, target_col: str):
    coin_df = df[df["symbol"] == coin].sort_values("date").reset_index(drop=True).copy()
    train_df, val_df, test_df, split_info = split_coin_df_manual_or_default(
        coin=coin,
        coin_df=coin_df,
        target_col=target_col,
    )

    coin_lookbacks = get_lookbacks_for_coin(coin)
    coin_selection_mode = get_selection_mode_for_coin(coin)
    coin_manual_weight = get_class_weight_for_coin(coin)
    oversample_multiplier = get_collapse_oversample_multiplier_for_coin(coin)

    print("\n" + "=" * 70)
    print(f"Coin: {coin}")
    print("=" * 70)
    print("Split info:", split_info)
    print("Selection mode:", coin_selection_mode)
    print("Lookbacks for this coin:", coin_lookbacks)
    print("Target:", target_col)
    print("Collapse benchmark eligible:", coin not in COLLAPSE_BENCHMARK_EXCLUDE)

    best_result = None
    best_selection_score = -np.inf
    candidate_rows = []

    for lookback in coin_lookbacks:
        X_train, y_train, _ = create_sequences(train_df, feature_cols, target_col, lookback)
        X_val, y_val, _ = create_sequences(val_df, feature_cols, target_col, lookback)
        X_test, y_test, test_dates = create_sequences(test_df, feature_cols, target_col, lookback)

        print(f"\n--- {coin} | lookback={lookback} ---")
        print("Train sequences:", X_train.shape)
        print("Val sequences  :", X_val.shape)
        print("Test sequences :", X_test.shape)

        if len(X_train) == 0 or len(X_val) == 0 or len(X_test) == 0:
            print("Skipping this lookback because one split has zero sequences.")
            continue

        print("Train label counts:", safe_label_counts(y_train))
        print("Val label counts  :", safe_label_counts(y_val))
        print("Test label counts :", safe_label_counts(y_test))
        print_split_warnings(coin, y_train, y_val, y_test)

        X_train_fit, y_train_fit = X_train, y_train
        if USE_COLLAPSE_OVERSAMPLING and oversample_multiplier > 1:
            X_train_fit, y_train_fit = oversample_target_class(
                X_train,
                y_train,
                target_class=COLLAPSE_CLASS,
                multiplier=oversample_multiplier,
                seed=SEED + int(lookback),
            )
            print(
                f"Oversampled collapse class with multiplier={oversample_multiplier}. "
                f"New train counts: {safe_label_counts(y_train_fit)}"
            )

        train_loader = make_loader(X_train_fit, y_train_fit, batch_size=BATCH_SIZE, shuffle=True)
        val_loader = make_loader(X_val, y_val, batch_size=BATCH_SIZE, shuffle=False)
        test_loader = make_loader(X_test, y_test, batch_size=BATCH_SIZE, shuffle=False)

        model = LSTMClassifier(
            input_size=len(feature_cols),
            hidden_size=HIDDEN_SIZE,
            num_layers=NUM_LAYERS,
            dropout=DROPOUT,
            dense_size=DENSE_SIZE,
            num_classes=3,
        ).to(DEVICE)

        if USE_CLASS_WEIGHTS:
            class_weights = get_class_weights(
                y_train_fit,
                mode=CLASS_WEIGHT_MODE,
                manual_weight=coin_manual_weight,
                num_classes=3,
            ).to(DEVICE)
            print("Using class weights:", class_weights.detach().cpu().numpy())
            criterion = nn.CrossEntropyLoss(weight=class_weights)
        else:
            print("Using unweighted CrossEntropyLoss()")
            criterion = nn.CrossEntropyLoss()

        optimizer = torch.optim.Adam(
            model.parameters(),
            lr=LEARNING_RATE,
            weight_decay=WEIGHT_DECAY,
        )

        best_weights = copy.deepcopy(model.state_dict())
        patience_counter = 0
        best_local_selection_score = -np.inf
        best_epoch_payload = None
        history = []

        for epoch in range(1, EPOCHS + 1):
            train_loss = train_one_epoch(model, train_loader, criterion, optimizer)

            val_loss_raw, y_val_true_raw, y_val_pred_argmax, val_probs = evaluate_loader(
                model, val_loader, criterion, collapse_threshold=None
            )

            if USE_COLLAPSE_THRESHOLD:
                selected_threshold, tuned_score, threshold_diag = tune_collapse_threshold(
                    coin=coin,
                    y_true=y_val_true_raw,
                    probs=val_probs,
                )
                y_val_pred = predict_with_collapse_threshold(val_probs, selected_threshold)
            else:
                selected_threshold = DEFAULT_FIXED_COLLAPSE_THRESHOLD
                threshold_diag = {}
                y_val_pred = y_val_pred_argmax

            val_macro_f1 = f1_score(y_val_true_raw, y_val_pred, average="macro", zero_division=0)
            val_weighted_f1 = f1_score(y_val_true_raw, y_val_pred, average="weighted", zero_division=0)
            val_pc = per_class_metrics(y_val_true_raw, y_val_pred)

            epoch_selection_score = compute_event_selection_score(
                coin=coin,
                creation_f1=val_pc[1]["f1"],
                collapse_f1=val_pc[2]["f1"],
                val_counts=safe_label_counts(y_val_true_raw),
            )

            history.append({
                "epoch": epoch,
                "train_loss": train_loss,
                "val_loss": val_loss_raw,
                "val_macro_f1": val_macro_f1,
                "val_weighted_f1": val_weighted_f1,
                "val_creation_f1": val_pc[1]["f1"],
                "val_collapse_f1": val_pc[2]["f1"],
                "val_collapse_recall": val_pc[2]["recall"],
                "selected_threshold": selected_threshold,
                "epoch_selection_score": epoch_selection_score,
            })

            print(
                f"Epoch {epoch:02d} | train_loss={train_loss:.4f} | val_loss={val_loss_raw:.4f} | "
                f"val_macro_f1={val_macro_f1:.4f} | val_creation_f1={val_pc[1]['f1']:.4f} | "
                f"val_collapse_f1={val_pc[2]['f1']:.4f} | threshold={selected_threshold:.2f} | "
                f"epoch_selection_score={epoch_selection_score:.4f} | val_weighted_f1={val_weighted_f1:.4f}"
            )

            if epoch_selection_score > best_local_selection_score:
                best_local_selection_score = epoch_selection_score
                best_weights = copy.deepcopy(model.state_dict())
                best_epoch_payload = {
                    "y_val_true": np.array(y_val_true_raw),
                    "y_val_pred": np.array(y_val_pred),
                    "val_macro_f1": float(val_macro_f1),
                    "val_weighted_f1": float(val_weighted_f1),
                    "val_creation_f1": float(val_pc[1]["f1"]),
                    "val_collapse_f1": float(val_pc[2]["f1"]),
                    "val_collapse_recall": float(val_pc[2]["recall"]),
                    "selection_score": float(epoch_selection_score),
                    "selected_threshold": float(selected_threshold),
                    "threshold_diagnostics": threshold_diag,
                }
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= PATIENCE:
                    print(f"Early stopping triggered at epoch {epoch}.")
                    break

        model.load_state_dict(best_weights)

        selected_threshold = best_epoch_payload["selected_threshold"] if best_epoch_payload is not None else DEFAULT_FIXED_COLLAPSE_THRESHOLD
        test_loss, y_test_true, y_test_pred, test_probs = evaluate_loader(
            model, test_loader, criterion, collapse_threshold=selected_threshold
        )
        test_macro_f1 = f1_score(y_test_true, y_test_pred, average="macro", zero_division=0)
        test_weighted_f1 = f1_score(y_test_true, y_test_pred, average="weighted", zero_division=0)

        if best_epoch_payload is None:
            _, y_val_true_best, _, val_probs_best = evaluate_loader(model, val_loader, criterion, collapse_threshold=None)
            selected_threshold, _, threshold_diag = tune_collapse_threshold(coin=coin, y_true=y_val_true_best, probs=val_probs_best)
            y_val_pred_best = predict_with_collapse_threshold(val_probs_best, selected_threshold)
            val_pc_best = per_class_metrics(y_val_true_best, y_val_pred_best)
            best_epoch_payload = {
                "y_val_true": np.array(y_val_true_best),
                "y_val_pred": np.array(y_val_pred_best),
                "val_macro_f1": float(f1_score(y_val_true_best, y_val_pred_best, average="macro", zero_division=0)),
                "val_weighted_f1": float(f1_score(y_val_true_best, y_val_pred_best, average="weighted", zero_division=0)),
                "val_creation_f1": float(val_pc_best[1]["f1"]),
                "val_collapse_f1": float(val_pc_best[2]["f1"]),
                "val_collapse_recall": float(val_pc_best[2]["recall"]),
                "selection_score": float(compute_event_selection_score(
                    coin=coin,
                    creation_f1=val_pc_best[1]["f1"],
                    collapse_f1=val_pc_best[2]["f1"],
                    val_counts=safe_label_counts(y_val_true_best),
                )),
                "selected_threshold": float(selected_threshold),
                "threshold_diagnostics": threshold_diag,
            }

        print("Selected collapse threshold:", round(float(selected_threshold), 4))
        print("Predicted test label counts:", safe_label_counts(y_test_pred))
        print("Test confusion matrix:")
        print(confusion_matrix(y_test_true, y_test_pred, labels=LABELS))

        candidate_metrics = {
            "val_macro_f1": best_epoch_payload["val_macro_f1"],
            "test_macro_f1": float(test_macro_f1),
            "test_weighted_f1": float(test_weighted_f1),
            "selection_score": float(best_epoch_payload["selection_score"]),
            "selected_threshold": float(selected_threshold),
        }

        candidate_row = build_candidate_row(
            coin=coin,
            target_col=target_col,
            lookback=lookback,
            selection_mode=coin_selection_mode,
            y_train=y_train,
            y_val=y_val,
            y_test=y_test,
            y_val_true=best_epoch_payload["y_val_true"],
            y_val_pred=best_epoch_payload["y_val_pred"],
            y_test_true=y_test_true,
            y_test_pred=y_test_pred,
            best_epoch_metrics=candidate_metrics,
        )
        candidate_rows.append(candidate_row)

        result = {
            "coin": coin,
            "lookback": lookback,
            "target_col": target_col,
            "benchmark_flag": benchmark_flag_for_coin(coin),
            "feature_mode": FEATURE_MODE,
            "feature_cols": feature_cols,
            "split_info": split_info,
            "history": pd.DataFrame(history),
            "model_state_dict": copy.deepcopy(model.state_dict()),
            "y_test": y_test_true,
            "y_pred": y_test_pred,
            "y_test_proba": test_probs,
            "test_dates": test_dates,
            "val_macro_f1": best_epoch_payload["val_macro_f1"],
            "test_macro_f1": test_macro_f1,
            "test_weighted_f1": test_weighted_f1,
            "selection_score": candidate_row["selection_score"],
            "selection_mode": coin_selection_mode,
            "selected_threshold": float(selected_threshold),
            "train_counts": safe_label_counts(y_train),
            "val_counts": safe_label_counts(y_val),
            "test_counts": safe_label_counts(y_test),
            "pred_test_counts": safe_label_counts(y_test_pred),
            "candidate_row": candidate_row,
            "candidate_table": None,
            "threshold_diagnostics": best_epoch_payload.get("threshold_diagnostics", {}),
        }

        if candidate_row["selection_score"] > best_selection_score:
            best_selection_score = candidate_row["selection_score"]
            best_result = result

    candidate_table = summarize_candidate_table(candidate_rows)

    if best_result is None:
        raise RuntimeError(f"No valid experiment result produced for coin={coin}")

    best_result["candidate_table"] = candidate_table
    print("\nCandidate diagnostics for selected coin:")
    display(candidate_table)

    return best_result

# %% [markdown]
# ## 13. Run Main Benchmark (`gsadf_map_90_lead`)
#
# Execute the final experiment for all selected coins using `gsadf_map_90_lead`.

# %%
all_results = []
for coin in COINS_TO_RUN:
    result = run_coin_experiment(
        coin=coin,
        df=df,
        feature_cols=FEATURE_COLS,
        target_col=TARGET_COL,
    )
    all_results.append(result)
# Out:
# ======================================================================
# Coin: ADA
# ======================================================================
# Split info: {'train_start': '2018-05-01', 'train_end': '2021-05-31', 'val_start': '2021-06-01', 'val_end': '2021-09-30', 'test_start': '2021-10-01', 'test_end': '2024-12-31', 'split_strategy': 'manual_data_aware', 'coin': 'ADA', 'target_col': 'gsadf_map_90_lead', 'candidate_val_start': '2021-06-01', 'candidate_test_start': '2021-10-01', 'raw_train_counts': {0: 914, 1: 202, 2: 11}, 'raw_val_counts': {1: 49, 2: 73}, 'raw_test_counts': {0: 1028, 1: 86, 2: 74}, 'collapse_benchmark_eligible': False}
# Selection mode: creation_only
# Lookbacks for this coin: [14, 21]
# Target: gsadf_map_90_lead
# Collapse benchmark eligible: False
#
# --- ADA | lookback=14 ---
# Train sequences: (1114, 14, 42)
# Val sequences  : (109, 14, 42)
# Test sequences : (1175, 14, 42)
# Train label counts: {0: 901, 1: 202, 2: 11}
# Val label counts  : {0: 0, 1: 44, 2: 65}
# Test label counts : {0: 1028, 1: 86, 2: 61}
# Using class weights: [1.  1.2 1.6]
# Epoch 01 | train_loss=1.0271 | val_loss=1.0860 | val_macro_f1=0.5363 | val_creation_f1=0.7246 | val_collapse_f1=0.8844 | threshold=0.30 | epoch_selection_score=0.7246 | val_weighted_f1=0.8199
# Epoch 02 | train_loss=0.8661 | val_loss=1.0980 | val_macro_f1=0.4861 | val_creation_f1=0.8108 | val_collapse_f1=0.6476 | threshold=0.30 | epoch_selection_score=0.8108 | val_weighted_f1=0.7135
# Epoch 03 | train_loss=0.5836 | val_loss=1.2122 | val_macro_f1=0.4044 | val_creation_f1=0.8718 | val_collapse_f1=0.3415 | threshold=0.30 | epoch_selection_score=0.8718 | val_weighted_f1=0.5555
# Epoch 04 | train_loss=0.3172 | val_loss=1.3173 | val_macro_f1=0.4812 | val_creation_f1=0.8780 | val_collapse_f1=0.5657 | threshold=0.25 | epoch_selection_score=0.8780 | val_weighted_f1=0.6918
# Epoch 05 | train_loss=0.2118 | val_loss=1.3726 | val_macro_f1=0.4754 | val_creation_f1=0.8989 | val_collapse_f1=0.5275 | threshold=0.25 | epoch_selection_score=0.8989 | val_weighted_f1=0.6774
# Epoch 06 | train_loss=0.1718 | val_loss=1.4162 | val_macro_f1=0.5375 | val_creation_f1=0.9268 | val_collapse_f1=0.6857 | threshold=0.20 | epoch_selection_score=0.9268 | val_weighted_f1=0.7830
# Epoch 07 | train_loss=0.1496 | val_loss=1.4149 | val_macro_f1=0.5113 | val_creation_f1=0.8736 | val_collapse_f1=0.6602 | threshold=0.20 | epoch_selection_score=0.8736 | val_weighted_f1=0.7463
# Epoch 08 | train_loss=0.1182 | val_loss=1.4820 | val_macro_f1=0.4771 | val_creation_f1=0.8539 | val_collapse_f1=0.5773 | threshold=0.20 | epoch_selection_score=0.8539 | val_weighted_f1=0.6890
# Epoch 09 | train_loss=0.1004 | val_loss=1.4649 | val_macro_f1=0.4867 | val_creation_f1=0.8478 | val_collapse_f1=0.6122 | threshold=0.20 | epoch_selection_score=0.8478 | val_weighted_f1=0.7073
# Epoch 10 | train_loss=0.0936 | val_loss=1.4781 | val_macro_f1=0.4804 | val_creation_f1=0.8454 | val_collapse_f1=0.5957 | threshold=0.20 | epoch_selection_score=0.8454 | val_weighted_f1=0.6965
# Early stopping triggered at epoch 10.
# Selected collapse threshold: 0.2
# Predicted test label counts: {0: 804, 1: 175, 2: 196}
# Test confusion matrix:
# [[787  98 143]
#  [  6  77   3]
#  [ 11   0  50]]
#
# --- ADA | lookback=21 ---
# Train sequences: (1107, 21, 42)
# Val sequences  : (102, 21, 42)
# Test sequences : (1168, 21, 42)
# Train label counts: {0: 894, 1: 202, 2: 11}
# Val label counts  : {0: 0, 1: 44, 2: 58}
# Test label counts : {0: 1028, 1: 84, 2: 56}
# Using class weights: [1.  1.2 1.6]
# Epoch 01 | train_loss=1.0913 | val_loss=1.0054 | val_macro_f1=0.5267 | val_creation_f1=0.7429 | val_collapse_f1=0.8372 | threshold=0.35 | epoch_selection_score=0.7429 | val_weighted_f1=0.7965
# Epoch 02 | train_loss=0.8731 | val_loss=1.0330 | val_macro_f1=0.5773 | val_creation_f1=0.9398 | val_collapse_f1=0.7921 | threshold=0.35 | epoch_selection_score=0.9398 | val_weighted_f1=0.8558
# Epoch 03 | train_loss=0.4650 | val_loss=1.1497 | val_macro_f1=0.2793 | val_creation_f1=0.8039 | val_collapse_f1=0.0339 | threshold=0.35 | epoch_selection_score=0.8039 | val_weighted_f1=0.3661
# Epoch 04 | train_loss=0.2752 | val_loss=1.2163 | val_macro_f1=0.4925 | val_creation_f1=0.8108 | val_collapse_f1=0.6667 | threshold=0.30 | epoch_selection_score=0.8108 | val_weighted_f1=0.7288
# Epoch 05 | train_loss=0.2197 | val_loss=1.2901 | val_macro_f1=0.4401 | val_creation_f1=0.9048 | val_collapse_f1=0.4156 | threshold=0.30 | epoch_selection_score=0.9048 | val_weighted_f1=0.6266
# Epoch 06 | train_loss=0.1706 | val_loss=1.2395 | val_macro_f1=0.3907 | val_creation_f1=0.8667 | val_collapse_f1=0.3056 | threshold=0.30 | epoch_selection_score=0.8667 | val_weighted_f1=0.5476
# Early stopping triggered at epoch 6.
# Selected collapse threshold: 0.35
# Predicted test label counts: {0: 872, 1: 240, 2: 56}
# Test confusion matrix:
# [[854 158  16]
#  [  1  82   1]
#  [ 17   0  39]]
#
# Candidate diagnostics for selected coin:
#   coin         target_col  lookback selection_mode  threshold  \
# 0  ADA  gsadf_map_90_lead        21  creation_only       0.35
# 1  ADA  gsadf_map_90_lead        14  creation_only       0.20
#
#    selection_score  val_macro_f1  val_creation_f1  val_collapse_f1  \
# 0         0.939759      0.577279         0.939759         0.792079
# 1         0.926829      0.537515         0.926829         0.685714
#
#    val_collapse_recall  test_macro_f1  test_creation_f1  test_collapse_f1  \
# 0             0.689655       0.700516          0.506173          0.696429
# 1             0.553846       0.612771          0.590038          0.389105
#
#    test_collapse_recall  train_collapse_n  val_collapse_n  test_collapse_n  \
# 0              0.696429                11              58               56
# 1              0.819672                11              65               61
#
#    pred_test_collapse_n
# 0                    56
# 1                   196
# ======================================================================
# Coin: BNB
# ======================================================================
# Split info: {'train_start': '2018-05-01', 'train_end': '2021-02-28', 'val_start': '2021-03-01', 'val_end': '2021-12-31', 'test_start': '2022-01-01', 'test_end': '2024-12-31', 'split_strategy': 'manual_data_aware', 'coin': 'BNB', 'target_col': 'gsadf_map_90_lead', 'candidate_val_start': '2021-03-01', 'candidate_test_start': '2022-01-01', 'raw_train_counts': {0: 970, 1: 45, 2: 20}, 'raw_val_counts': {1: 193, 2: 113}, 'raw_test_counts': {0: 930, 1: 109, 2: 57}, 'collapse_benchmark_eligible': True}
# Selection mode: creation_collapse_weighted
# Lookbacks for this coin: [14, 21, 30]
# Target: gsadf_map_90_lead
# Collapse benchmark eligible: True
#
# --- BNB | lookback=14 ---
# Train sequences: (1022, 14, 42)
# Val sequences  : (293, 14, 42)
# Test sequences : (1083, 14, 42)
# Train label counts: {0: 957, 1: 45, 2: 20}
# Val label counts  : {0: 0, 1: 180, 2: 113}
# Test label counts : {0: 930, 1: 109, 2: 44}
# Oversampled collapse class with multiplier=5. New train counts: {0: 957, 1: 45, 2: 100}
# Using class weights: [1.  1.2 6.8]
# Epoch 01 | train_loss=1.0730 | val_loss=1.0882 | val_macro_f1=0.2067 | val_creation_f1=0.2772 | val_collapse_f1=0.3429 | threshold=0.35 | epoch_selection_score=0.3068 | val_weighted_f1=0.3025
# Epoch 02 | train_loss=0.9224 | val_loss=1.1235 | val_macro_f1=0.2071 | val_creation_f1=0.0000 | val_collapse_f1=0.6214 | threshold=0.30 | epoch_selection_score=0.2796 | val_weighted_f1=0.2397
# Epoch 03 | train_loss=0.6143 | val_loss=1.2220 | val_macro_f1=0.1940 | val_creation_f1=0.0000 | val_collapse_f1=0.5820 | threshold=0.20 | epoch_selection_score=0.2619 | val_weighted_f1=0.2245
# Epoch 04 | train_loss=0.3499 | val_loss=1.3246 | val_macro_f1=0.1915 | val_creation_f1=0.0000 | val_collapse_f1=0.5744 | threshold=0.15 | epoch_selection_score=0.2585 | val_weighted_f1=0.2215
# Epoch 05 | train_loss=0.2586 | val_loss=1.3256 | val_macro_f1=0.1852 | val_creation_f1=0.0000 | val_collapse_f1=0.5556 | threshold=0.15 | epoch_selection_score=0.2500 | val_weighted_f1=0.2143
# Early stopping triggered at epoch 5.
# Selected collapse threshold: 0.35
# Predicted test label counts: {0: 467, 1: 356, 2: 260}
# Test confusion matrix:
# [[410 273 247]
#  [ 55  54   0]
#  [  2  29  13]]
#
# --- BNB | lookback=21 ---
# Train sequences: (1015, 21, 42)
# Val sequences  : (286, 21, 42)
# Test sequences : (1076, 21, 42)
# Train label counts: {0: 950, 1: 45, 2: 20}
# Val label counts  : {0: 0, 1: 174, 2: 112}
# Test label counts : {0: 929, 1: 109, 2: 38}
# Oversampled collapse class with multiplier=5. New train counts: {0: 950, 1: 45, 2: 100}
# Using class weights: [1.  1.2 6.8]
# Epoch 01 | train_loss=1.0424 | val_loss=1.1860 | val_macro_f1=0.2814 | val_creation_f1=0.0000 | val_collapse_f1=0.5628 | threshold=0.15 | epoch_selection_score=0.2533 | val_weighted_f1=0.2204
# Epoch 02 | train_loss=0.9078 | val_loss=1.1861 | val_macro_f1=0.2627 | val_creation_f1=0.0000 | val_collapse_f1=0.7882 | threshold=0.30 | epoch_selection_score=0.3547 | val_weighted_f1=0.3087
# Epoch 03 | train_loss=0.6750 | val_loss=1.2757 | val_macro_f1=0.2479 | val_creation_f1=0.0000 | val_collapse_f1=0.7438 | threshold=0.25 | epoch_selection_score=0.3347 | val_weighted_f1=0.2913
# Epoch 04 | train_loss=0.4492 | val_loss=1.6473 | val_macro_f1=0.1696 | val_creation_f1=0.0000 | val_collapse_f1=0.5087 | threshold=0.25 | epoch_selection_score=0.2289 | val_weighted_f1=0.1992
# Epoch 05 | train_loss=0.3763 | val_loss=1.5017 | val_macro_f1=0.1640 | val_creation_f1=0.0000 | val_collapse_f1=0.4920 | threshold=0.25 | epoch_selection_score=0.2214 | val_weighted_f1=0.1927
# Epoch 06 | train_loss=0.2265 | val_loss=1.6695 | val_macro_f1=0.1623 | val_creation_f1=0.0000 | val_collapse_f1=0.4868 | threshold=0.30 | epoch_selection_score=0.2191 | val_weighted_f1=0.1907
# Early stopping triggered at epoch 6.
# Selected collapse threshold: 0.3
# Predicted test label counts: {0: 619, 1: 0, 2: 457}
# Test confusion matrix:
# [[495   0 434]
#  [108   0   1]
#  [ 16   0  22]]
#
# --- BNB | lookback=30 ---
# Train sequences: (1006, 30, 42)
# Val sequences  : (277, 30, 42)
# Test sequences : (1067, 30, 42)
# Train label counts: {0: 941, 1: 45, 2: 20}
# Val label counts  : {0: 0, 1: 167, 2: 110}
# Test label counts : {0: 920, 1: 109, 2: 38}
# Oversampled collapse class with multiplier=5. New train counts: {0: 941, 1: 45, 2: 100}
# Using class weights: [1.  1.2 6.8]
# Epoch 01 | train_loss=1.0235 | val_loss=1.0962 | val_macro_f1=0.2356 | val_creation_f1=0.0000 | val_collapse_f1=0.7068 | threshold=0.35 | epoch_selection_score=0.3181 | val_weighted_f1=0.2807
# Epoch 02 | train_loss=0.8971 | val_loss=1.1050 | val_macro_f1=0.2200 | val_creation_f1=0.0000 | val_collapse_f1=0.6599 | threshold=0.35 | epoch_selection_score=0.2970 | val_weighted_f1=0.2621
# Epoch 03 | train_loss=0.6757 | val_loss=1.2604 | val_macro_f1=0.2842 | val_creation_f1=0.0000 | val_collapse_f1=0.5685 | threshold=0.15 | epoch_selection_score=0.2558 | val_weighted_f1=0.2257
# Epoch 04 | train_loss=0.3664 | val_loss=1.5117 | val_macro_f1=0.1754 | val_creation_f1=0.0000 | val_collapse_f1=0.5263 | threshold=0.35 | epoch_selection_score=0.2368 | val_weighted_f1=0.2090
# Epoch 05 | train_loss=0.2106 | val_loss=1.6076 | val_macro_f1=0.1743 | val_creation_f1=0.0000 | val_collapse_f1=0.5229 | threshold=0.35 | epoch_selection_score=0.2353 | val_weighted_f1=0.2076
# Early stopping triggered at epoch 5.
# Selected collapse threshold: 0.35
# Predicted test label counts: {0: 124, 1: 0, 2: 943}
# Test confusion matrix:
# [[ 91   0 829]
#  [ 33   0  76]
#  [  0   0  38]]
#
# Candidate diagnostics for selected coin:
#   coin         target_col  lookback              selection_mode  threshold  \
# 0  BNB  gsadf_map_90_lead        21  creation_collapse_weighted       0.30
# 1  BNB  gsadf_map_90_lead        30  creation_collapse_weighted       0.35
# 2  BNB  gsadf_map_90_lead        14  creation_collapse_weighted       0.35
#
#    selection_score  val_macro_f1  val_creation_f1  val_collapse_f1  \
# 0         0.354680      0.262726         0.000000         0.788177
# 1         0.318072      0.235609         0.000000         0.706827
# 2         0.306761      0.206695         0.277228         0.342857
#
#    val_collapse_recall  test_macro_f1  test_creation_f1  test_collapse_f1  \
# 0             0.714286       0.242808          0.000000          0.088889
# 1             0.800000       0.083934          0.000000          0.077472
# 2             0.212389       0.301585          0.232258          0.085526
#
#    test_collapse_recall  train_collapse_n  val_collapse_n  test_collapse_n  \
# 0              0.578947                20             112               38
# 1              1.000000                20             110               38
# 2              0.295455                20             113               44
#
#    pred_test_collapse_n
# 0                   457
# 1                   943
# 2                   260
# ======================================================================
# Coin: BTC
# ======================================================================
# Split info: {'train_start': '2018-05-01', 'train_end': '2021-02-28', 'val_start': '2021-03-01', 'val_end': '2021-12-31', 'test_start': '2022-01-01', 'test_end': '2024-12-31', 'split_strategy': 'manual_data_aware', 'coin': 'BTC', 'target_col': 'gsadf_map_90_lead', 'candidate_val_start': '2021-03-01', 'candidate_test_start': '2022-01-01', 'raw_train_counts': {0: 882, 1: 134, 2: 19}, 'raw_val_counts': {0: 139, 1: 114, 2: 53}, 'raw_test_counts': {0: 882, 1: 164, 2: 50}, 'collapse_benchmark_eligible': True}
# Selection mode: creation_collapse_weighted
# Lookbacks for this coin: [14, 21, 30]
# Target: gsadf_map_90_lead
# Collapse benchmark eligible: True
#
# --- BTC | lookback=14 ---
# Train sequences: (1022, 14, 42)
# Val sequences  : (293, 14, 42)
# Test sequences : (1083, 14, 42)
# Train label counts: {0: 869, 1: 134, 2: 19}
# Val label counts  : {0: 139, 1: 101, 2: 53}
# Test label counts : {0: 869, 1: 164, 2: 50}
# Oversampled collapse class with multiplier=4. New train counts: {0: 869, 1: 134, 2: 76}
# Using class weights: [1.  1.2 1.6]
# Epoch 01 | train_loss=1.0110 | val_loss=1.0352 | val_macro_f1=0.4085 | val_creation_f1=0.0000 | val_collapse_f1=0.3750 | threshold=0.30 | epoch_selection_score=0.1688 | val_weighted_f1=0.4713
# Epoch 02 | train_loss=0.8764 | val_loss=0.9343 | val_macro_f1=0.4269 | val_creation_f1=0.1296 | val_collapse_f1=0.3894 | threshold=0.30 | epoch_selection_score=0.2465 | val_weighted_f1=0.4764
# Epoch 03 | train_loss=0.6495 | val_loss=0.8278 | val_macro_f1=0.5935 | val_creation_f1=0.6194 | val_collapse_f1=0.3944 | threshold=0.30 | epoch_selection_score=0.5181 | val_weighted_f1=0.6485
# Epoch 04 | train_loss=0.4584 | val_loss=0.7937 | val_macro_f1=0.7226 | val_creation_f1=0.6982 | val_collapse_f1=0.5932 | threshold=0.25 | epoch_selection_score=0.6510 | val_weighted_f1=0.7637
# Epoch 05 | train_loss=0.3393 | val_loss=0.7492 | val_macro_f1=0.7495 | val_creation_f1=0.8000 | val_collapse_f1=0.5965 | threshold=0.25 | epoch_selection_score=0.7084 | val_weighted_f1=0.7878
# Epoch 06 | train_loss=0.2649 | val_loss=0.7338 | val_macro_f1=0.7412 | val_creation_f1=0.7980 | val_collapse_f1=0.5664 | threshold=0.25 | epoch_selection_score=0.6938 | val_weighted_f1=0.7852
# Epoch 07 | train_loss=0.2162 | val_loss=0.7447 | val_macro_f1=0.7166 | val_creation_f1=0.7778 | val_collapse_f1=0.5424 | threshold=0.25 | epoch_selection_score=0.6718 | val_weighted_f1=0.7598
# Epoch 08 | train_loss=0.1846 | val_loss=0.7269 | val_macro_f1=0.7312 | val_creation_f1=0.7980 | val_collapse_f1=0.5546 | threshold=0.25 | epoch_selection_score=0.6885 | val_weighted_f1=0.7743
# Epoch 09 | train_loss=0.1654 | val_loss=0.7598 | val_macro_f1=0.6855 | val_creation_f1=0.7795 | val_collapse_f1=0.5037 | threshold=0.25 | epoch_selection_score=0.6554 | val_weighted_f1=0.7267
# Early stopping triggered at epoch 9.
# Selected collapse threshold: 0.25
# Predicted test label counts: {0: 634, 1: 145, 2: 304}
# Test confusion matrix:
# [[605  50 214]
#  [  2  94  68]
#  [ 27   1  22]]
#
# --- BTC | lookback=21 ---
# Train sequences: (1015, 21, 42)
# Val sequences  : (286, 21, 42)
# Test sequences : (1076, 21, 42)
# Train label counts: {0: 862, 1: 134, 2: 19}
# Val label counts  : {0: 139, 1: 94, 2: 53}
# Test label counts : {0: 862, 1: 164, 2: 50}
# Oversampled collapse class with multiplier=4. New train counts: {0: 862, 1: 134, 2: 76}
# Using class weights: [1.  1.2 1.6]
# Epoch 01 | train_loss=0.9989 | val_loss=1.0221 | val_macro_f1=0.1042 | val_creation_f1=0.0000 | val_collapse_f1=0.3127 | threshold=0.15 | epoch_selection_score=0.1407 | val_weighted_f1=0.0579
# Epoch 02 | train_loss=0.8436 | val_loss=0.9105 | val_macro_f1=0.5207 | val_creation_f1=0.3793 | val_collapse_f1=0.3699 | threshold=0.25 | epoch_selection_score=0.3751 | val_weighted_f1=0.5883
# Epoch 03 | train_loss=0.5956 | val_loss=0.8263 | val_macro_f1=0.6613 | val_creation_f1=0.6579 | val_collapse_f1=0.4848 | threshold=0.25 | epoch_selection_score=0.5800 | val_weighted_f1=0.7149
# Epoch 04 | train_loss=0.4441 | val_loss=0.7979 | val_macro_f1=0.6896 | val_creation_f1=0.7717 | val_collapse_f1=0.4557 | threshold=0.25 | epoch_selection_score=0.6295 | val_weighted_f1=0.7470
# Epoch 05 | train_loss=0.3440 | val_loss=0.7740 | val_macro_f1=0.6960 | val_creation_f1=0.8041 | val_collapse_f1=0.4587 | threshold=0.25 | epoch_selection_score=0.6487 | val_weighted_f1=0.7504
# Epoch 06 | train_loss=0.2670 | val_loss=0.7893 | val_macro_f1=0.6030 | val_creation_f1=0.8218 | val_collapse_f1=0.3899 | threshold=0.25 | epoch_selection_score=0.6275 | val_weighted_f1=0.6326
# Epoch 07 | train_loss=0.2115 | val_loss=0.7878 | val_macro_f1=0.5665 | val_creation_f1=0.8168 | val_collapse_f1=0.4205 | threshold=0.20 | epoch_selection_score=0.6384 | val_weighted_f1=0.5711
# Epoch 08 | train_loss=0.1852 | val_loss=0.7770 | val_macro_f1=0.5699 | val_creation_f1=0.8168 | val_collapse_f1=0.4167 | threshold=0.20 | epoch_selection_score=0.6367 | val_weighted_f1=0.5771
# Epoch 09 | train_loss=0.1588 | val_loss=0.7835 | val_macro_f1=0.5622 | val_creation_f1=0.7956 | val_collapse_f1=0.4381 | threshold=0.15 | epoch_selection_score=0.6347 | val_weighted_f1=0.5629
# Early stopping triggered at epoch 9.
# Selected collapse threshold: 0.25
# Predicted test label counts: {0: 597, 1: 242, 2: 237}
# Test confusion matrix:
# [[570  97 195]
#  [  0 137  27]
#  [ 27   8  15]]
#
# --- BTC | lookback=30 ---
# Train sequences: (1006, 30, 42)
# Val sequences  : (277, 30, 42)
# Test sequences : (1067, 30, 42)
# Train label counts: {0: 853, 1: 134, 2: 19}
# Val label counts  : {0: 139, 1: 88, 2: 50}
# Test label counts : {0: 854, 1: 164, 2: 49}
# Oversampled collapse class with multiplier=4. New train counts: {0: 853, 1: 134, 2: 76}
# Using class weights: [1.  1.2 1.6]
# Epoch 01 | train_loss=1.1081 | val_loss=1.0601 | val_macro_f1=0.3748 | val_creation_f1=0.5556 | val_collapse_f1=0.5688 | threshold=0.30 | epoch_selection_score=0.5615 | val_weighted_f1=0.2792
# Epoch 02 | train_loss=0.8779 | val_loss=0.9417 | val_macro_f1=0.6782 | val_creation_f1=0.5714 | val_collapse_f1=0.6824 | threshold=0.30 | epoch_selection_score=0.6213 | val_weighted_f1=0.6966
# Epoch 03 | train_loss=0.5802 | val_loss=0.8272 | val_macro_f1=0.6848 | val_creation_f1=0.5899 | val_collapse_f1=0.6429 | threshold=0.30 | epoch_selection_score=0.6137 | val_weighted_f1=0.7158
# Epoch 04 | train_loss=0.4063 | val_loss=0.7922 | val_macro_f1=0.7547 | val_creation_f1=0.7673 | val_collapse_f1=0.6444 | threshold=0.30 | epoch_selection_score=0.7120 | val_weighted_f1=0.7879
# Epoch 05 | train_loss=0.3252 | val_loss=0.7641 | val_macro_f1=0.7855 | val_creation_f1=0.8324 | val_collapse_f1=0.6522 | threshold=0.30 | epoch_selection_score=0.7513 | val_weighted_f1=0.8197
# Epoch 06 | train_loss=0.2685 | val_loss=0.7706 | val_macro_f1=0.7615 | val_creation_f1=0.8208 | val_collapse_f1=0.6105 | threshold=0.30 | epoch_selection_score=0.7262 | val_weighted_f1=0.7991
# Epoch 07 | train_loss=0.2352 | val_loss=0.7517 | val_macro_f1=0.7601 | val_creation_f1=0.8427 | val_collapse_f1=0.5941 | threshold=0.30 | epoch_selection_score=0.7308 | val_weighted_f1=0.7983
# Epoch 08 | train_loss=0.2127 | val_loss=0.7254 | val_macro_f1=0.7761 | val_creation_f1=0.8049 | val_collapse_f1=0.6847 | threshold=0.25 | epoch_selection_score=0.7508 | val_weighted_f1=0.8002
# Epoch 09 | train_loss=0.1892 | val_loss=0.7115 | val_macro_f1=0.7983 | val_creation_f1=0.8214 | val_collapse_f1=0.7184 | threshold=0.25 | epoch_selection_score=0.7751 | val_weighted_f1=0.8197
# Epoch 10 | train_loss=0.1608 | val_loss=0.6926 | val_macro_f1=0.7979 | val_creation_f1=0.8235 | val_collapse_f1=0.7071 | threshold=0.25 | epoch_selection_score=0.7711 | val_weighted_f1=0.8224
# Epoch 11 | train_loss=0.1359 | val_loss=0.6939 | val_macro_f1=0.7923 | val_creation_f1=0.8208 | val_collapse_f1=0.6939 | threshold=0.25 | epoch_selection_score=0.7637 | val_weighted_f1=0.8187
# Epoch 12 | train_loss=0.1219 | val_loss=0.7137 | val_macro_f1=0.7777 | val_creation_f1=0.8046 | val_collapse_f1=0.6804 | threshold=0.25 | epoch_selection_score=0.7487 | val_weighted_f1=0.8040
# Epoch 13 | train_loss=0.1129 | val_loss=0.7091 | val_macro_f1=0.7600 | val_creation_f1=0.8068 | val_collapse_f1=0.6471 | threshold=0.25 | epoch_selection_score=0.7349 | val_weighted_f1=0.7876
# Early stopping triggered at epoch 13.
# Selected collapse threshold: 0.25
# Predicted test label counts: {0: 610, 1: 202, 2: 255}
# Test confusion matrix:
# [[584  83 187]
#  [  0 118  46]
#  [ 26   1  22]]
#
# Candidate diagnostics for selected coin:
#   coin         target_col  lookback              selection_mode  threshold  \
# 0  BTC  gsadf_map_90_lead        30  creation_collapse_weighted       0.25
# 1  BTC  gsadf_map_90_lead        14  creation_collapse_weighted       0.25
# 2  BTC  gsadf_map_90_lead        21  creation_collapse_weighted       0.25
#
#    selection_score  val_macro_f1  val_creation_f1  val_collapse_f1  \
# 0         0.775087      0.798333         0.821429         0.718447
# 1         0.708421      0.749492         0.800000         0.596491
# 2         0.648690      0.696039         0.804124         0.458716
#
#    val_collapse_recall  test_macro_f1  test_creation_f1  test_collapse_f1  \
# 0             0.740000       0.529120          0.644809          0.144737
# 1             0.641509       0.512588          0.608414          0.124294
# 2             0.471698       0.520255          0.674877          0.104530
#
#    test_collapse_recall  train_collapse_n  val_collapse_n  test_collapse_n  \
# 0               0.44898                19              50               49
# 1               0.44000                19              53               50
# 2               0.30000                19              53               50
#
#    pred_test_collapse_n
# 0                   255
# 1                   304
# 2                   237
# ======================================================================
# Coin: DOGE
# ======================================================================
# Split info: {'train_start': '2019-07-05', 'train_end': '2021-05-31', 'val_start': '2021-06-01', 'val_end': '2021-08-31', 'test_start': '2021-09-01', 'test_end': '2024-12-31', 'split_strategy': 'manual_data_aware', 'coin': 'DOGE', 'target_col': 'gsadf_map_90_lead', 'candidate_val_start': '2021-06-01', 'candidate_test_start': '2021-09-01', 'raw_train_counts': {0: 550, 1: 128, 2: 19}, 'raw_val_counts': {1: 28, 2: 64}, 'raw_test_counts': {0: 1082, 1: 103, 2: 33}, 'collapse_benchmark_eligible': False}
# Selection mode: creation_only
# Lookbacks for this coin: [14, 21]
# Target: gsadf_map_90_lead
# Collapse benchmark eligible: False
#
# --- DOGE | lookback=14 ---
# Train sequences: (684, 14, 42)
# Val sequences  : (79, 14, 42)
# Test sequences : (1205, 14, 42)
# Train label counts: {0: 537, 1: 128, 2: 19}
# Val label counts  : {0: 0, 1: 28, 2: 51}
# Test label counts : {0: 1082, 1: 96, 2: 27}
# Using class weights: [1.  1.2 1.6]
# Epoch 01 | train_loss=0.9185 | val_loss=1.2174 | val_macro_f1=0.3923 | val_creation_f1=0.0000 | val_collapse_f1=0.7846 | threshold=0.20 | epoch_selection_score=0.0000 | val_weighted_f1=0.5065
# Epoch 02 | train_loss=0.8220 | val_loss=1.2083 | val_macro_f1=0.3923 | val_creation_f1=0.0000 | val_collapse_f1=0.7846 | threshold=0.20 | epoch_selection_score=0.0000 | val_weighted_f1=0.5065
# Epoch 03 | train_loss=0.6539 | val_loss=1.1926 | val_macro_f1=0.4796 | val_creation_f1=0.6341 | val_collapse_f1=0.8046 | threshold=0.25 | epoch_selection_score=0.6341 | val_weighted_f1=0.7442
# Epoch 04 | train_loss=0.4403 | val_loss=1.1825 | val_macro_f1=0.3954 | val_creation_f1=0.7556 | val_collapse_f1=0.4308 | threshold=0.25 | epoch_selection_score=0.7556 | val_weighted_f1=0.5459
# Epoch 05 | train_loss=0.3027 | val_loss=1.1682 | val_macro_f1=0.3738 | val_creation_f1=0.8800 | val_collapse_f1=0.2414 | threshold=0.25 | epoch_selection_score=0.8800 | val_weighted_f1=0.4677
# Epoch 06 | train_loss=0.2367 | val_loss=1.1507 | val_macro_f1=0.3981 | val_creation_f1=0.9231 | val_collapse_f1=0.2712 | threshold=0.25 | epoch_selection_score=0.9231 | val_weighted_f1=0.5022
# Epoch 07 | train_loss=0.1998 | val_loss=1.1257 | val_macro_f1=0.4414 | val_creation_f1=0.9434 | val_collapse_f1=0.3810 | threshold=0.25 | epoch_selection_score=0.9434 | val_weighted_f1=0.5803
# Epoch 08 | train_loss=0.1867 | val_loss=1.1031 | val_macro_f1=0.4737 | val_creation_f1=0.9434 | val_collapse_f1=0.4776 | threshold=0.25 | epoch_selection_score=0.9434 | val_weighted_f1=0.6427
# Epoch 09 | train_loss=0.1709 | val_loss=1.0843 | val_macro_f1=0.5023 | val_creation_f1=0.9434 | val_collapse_f1=0.5634 | threshold=0.25 | epoch_selection_score=0.9434 | val_weighted_f1=0.6981
# Epoch 10 | train_loss=0.1617 | val_loss=1.0543 | val_macro_f1=0.5338 | val_creation_f1=0.9434 | val_collapse_f1=0.6579 | threshold=0.25 | epoch_selection_score=0.9434 | val_weighted_f1=0.7591
# Epoch 11 | train_loss=0.1566 | val_loss=1.0265 | val_macro_f1=0.5561 | val_creation_f1=0.9434 | val_collapse_f1=0.7250 | threshold=0.25 | epoch_selection_score=0.9434 | val_weighted_f1=0.8024
# Early stopping triggered at epoch 11.
# Selected collapse threshold: 0.25
# Predicted test label counts: {0: 948, 1: 179, 2: 78}
# Test confusion matrix:
# [[916  96  70]
#  [ 15  81   0]
#  [ 17   2   8]]
#
# --- DOGE | lookback=21 ---
# Train sequences: (677, 21, 42)
# Val sequences  : (72, 21, 42)
# Test sequences : (1198, 21, 42)
# Train label counts: {0: 530, 1: 128, 2: 19}
# Val label counts  : {0: 0, 1: 28, 2: 44}
# Test label counts : {0: 1080, 1: 96, 2: 22}
# Using class weights: [1.  1.2 1.6]
# Epoch 01 | train_loss=1.1032 | val_loss=1.0789 | val_macro_f1=0.2800 | val_creation_f1=0.5600 | val_collapse_f1=0.0000 | threshold=0.30 | epoch_selection_score=0.5600 | val_weighted_f1=0.2178
# Epoch 02 | train_loss=1.0067 | val_loss=1.0756 | val_macro_f1=0.2800 | val_creation_f1=0.5600 | val_collapse_f1=0.0000 | threshold=0.30 | epoch_selection_score=0.5600 | val_weighted_f1=0.2178
# Epoch 03 | train_loss=0.8676 | val_loss=1.0705 | val_macro_f1=0.2800 | val_creation_f1=0.5600 | val_collapse_f1=0.0000 | threshold=0.30 | epoch_selection_score=0.5600 | val_weighted_f1=0.2178
# Epoch 04 | train_loss=0.6618 | val_loss=1.0643 | val_macro_f1=0.2800 | val_creation_f1=0.5600 | val_collapse_f1=0.0000 | threshold=0.30 | epoch_selection_score=0.5600 | val_weighted_f1=0.2178
# Epoch 05 | train_loss=0.4363 | val_loss=1.0561 | val_macro_f1=0.3968 | val_creation_f1=0.5895 | val_collapse_f1=0.2041 | threshold=0.30 | epoch_selection_score=0.5895 | val_weighted_f1=0.3540
# Epoch 06 | train_loss=0.2787 | val_loss=1.0313 | val_macro_f1=0.5146 | val_creation_f1=0.6292 | val_collapse_f1=0.4000 | threshold=0.30 | epoch_selection_score=0.6292 | val_weighted_f1=0.4891
# Epoch 07 | train_loss=0.2514 | val_loss=1.0055 | val_macro_f1=0.6160 | val_creation_f1=0.6747 | val_collapse_f1=0.5574 | threshold=0.30 | epoch_selection_score=0.6747 | val_weighted_f1=0.6030
# Epoch 08 | train_loss=0.2046 | val_loss=0.9878 | val_macro_f1=0.6160 | val_creation_f1=0.6747 | val_collapse_f1=0.5574 | threshold=0.30 | epoch_selection_score=0.6747 | val_weighted_f1=0.6030
# Epoch 09 | train_loss=0.1789 | val_loss=0.9611 | val_macro_f1=0.6473 | val_creation_f1=0.6914 | val_collapse_f1=0.6032 | threshold=0.30 | epoch_selection_score=0.6914 | val_weighted_f1=0.6375
# Epoch 10 | train_loss=0.1554 | val_loss=0.9268 | val_macro_f1=0.6775 | val_creation_f1=0.7089 | val_collapse_f1=0.6462 | threshold=0.30 | epoch_selection_score=0.7089 | val_weighted_f1=0.6705
# Epoch 11 | train_loss=0.1522 | val_loss=0.9031 | val_macro_f1=0.6775 | val_creation_f1=0.7089 | val_collapse_f1=0.6462 | threshold=0.30 | epoch_selection_score=0.7089 | val_weighted_f1=0.6705
# Epoch 12 | train_loss=0.1558 | val_loss=0.8883 | val_macro_f1=0.5070 | val_creation_f1=0.7606 | val_collapse_f1=0.7606 | threshold=0.30 | epoch_selection_score=0.7606 | val_weighted_f1=0.7606
# Epoch 13 | train_loss=0.1353 | val_loss=0.8636 | val_macro_f1=0.5216 | val_creation_f1=0.7647 | val_collapse_f1=0.8000 | threshold=0.30 | epoch_selection_score=0.7647 | val_weighted_f1=0.7863
# Epoch 14 | train_loss=0.1356 | val_loss=0.8420 | val_macro_f1=0.5254 | val_creation_f1=0.7761 | val_collapse_f1=0.8000 | threshold=0.30 | epoch_selection_score=0.7761 | val_weighted_f1=0.7907
# Epoch 15 | train_loss=0.1319 | val_loss=0.8296 | val_macro_f1=0.5346 | val_creation_f1=0.7879 | val_collapse_f1=0.8158 | threshold=0.30 | epoch_selection_score=0.7879 | val_weighted_f1=0.8049
# Selected collapse threshold: 0.3
# Predicted test label counts: {0: 828, 1: 259, 2: 111}
# Test confusion matrix:
# [[801 179 100]
#  [ 14  79   3]
#  [ 13   1   8]]
#
# Candidate diagnostics for selected coin:
#    coin         target_col  lookback selection_mode  threshold  \
# 0  DOGE  gsadf_map_90_lead        14  creation_only       0.25
# 1  DOGE  gsadf_map_90_lead        21  creation_only       0.30
#
#    selection_score  val_macro_f1  val_creation_f1  val_collapse_f1  \
# 0         0.943396      0.441450         0.943396         0.380952
# 1         0.787879      0.534556         0.787879         0.815789
#
#    val_collapse_recall  test_macro_f1  test_creation_f1  test_collapse_f1  \
# 0             0.235294       0.547978          0.589091          0.152381
# 1             0.704545       0.468331          0.445070          0.120301
#
#    test_collapse_recall  train_collapse_n  val_collapse_n  test_collapse_n  \
# 0              0.296296                19              51               27
# 1              0.363636                19              44               22
#
#    pred_test_collapse_n
# 0                    78
# 1                   111
# ======================================================================
# Coin: ETH
# ======================================================================
# Split info: {'train_start': '2018-05-01', 'train_end': '2021-05-31', 'val_start': '2021-06-01', 'val_end': '2021-12-31', 'test_start': '2022-01-01', 'test_end': '2024-12-31', 'split_strategy': 'manual_data_aware', 'coin': 'ETH', 'target_col': 'gsadf_map_90_lead', 'candidate_val_start': '2021-06-01', 'candidate_test_start': '2022-01-01', 'raw_train_counts': {0: 924, 1: 187, 2: 16}, 'raw_val_counts': {0: 4, 1: 115, 2: 95}, 'raw_test_counts': {0: 990, 1: 54, 2: 52}, 'collapse_benchmark_eligible': True}
# Selection mode: creation_collapse_weighted
# Lookbacks for this coin: [14, 21, 30]
# Target: gsadf_map_90_lead
# Collapse benchmark eligible: True
#
# --- ETH | lookback=14 ---
# Train sequences: (1114, 14, 42)
# Val sequences  : (201, 14, 42)
# Test sequences : (1083, 14, 42)
# Train label counts: {0: 911, 1: 187, 2: 16}
# Val label counts  : {0: 4, 1: 115, 2: 82}
# Test label counts : {0: 987, 1: 54, 2: 42}
# Oversampled collapse class with multiplier=4. New train counts: {0: 911, 1: 187, 2: 64}
# Using class weights: [1.  1.3 6.8]
# Epoch 01 | train_loss=0.9927 | val_loss=1.2048 | val_macro_f1=0.1939 | val_creation_f1=0.0000 | val_collapse_f1=0.5816 | threshold=0.20 | epoch_selection_score=0.2617 | val_weighted_f1=0.2373
# Epoch 02 | train_loss=0.7614 | val_loss=1.3167 | val_macro_f1=0.3150 | val_creation_f1=0.0000 | val_collapse_f1=0.5639 | threshold=0.10 | epoch_selection_score=0.2538 | val_weighted_f1=0.2376
# Epoch 03 | train_loss=0.5520 | val_loss=1.5120 | val_macro_f1=0.4160 | val_creation_f1=0.6550 | val_collapse_f1=0.5113 | threshold=0.30 | epoch_selection_score=0.5903 | val_weighted_f1=0.5849
# Epoch 04 | train_loss=0.4817 | val_loss=1.5775 | val_macro_f1=0.4190 | val_creation_f1=0.5256 | val_collapse_f1=0.5714 | threshold=0.30 | epoch_selection_score=0.5462 | val_weighted_f1=0.5370
# Epoch 05 | train_loss=0.4311 | val_loss=1.4390 | val_macro_f1=0.5608 | val_creation_f1=0.8205 | val_collapse_f1=0.7051 | threshold=0.35 | epoch_selection_score=0.7686 | val_weighted_f1=0.7602
# Epoch 06 | train_loss=0.3403 | val_loss=1.2204 | val_macro_f1=0.5415 | val_creation_f1=0.7222 | val_collapse_f1=0.7072 | threshold=0.35 | epoch_selection_score=0.7155 | val_weighted_f1=0.7056
# Epoch 07 | train_loss=0.2491 | val_loss=0.9815 | val_macro_f1=0.5622 | val_creation_f1=0.7293 | val_collapse_f1=0.7351 | threshold=0.35 | epoch_selection_score=0.7319 | val_weighted_f1=0.7216
# Epoch 08 | train_loss=0.1908 | val_loss=0.9048 | val_macro_f1=0.5659 | val_creation_f1=0.7363 | val_collapse_f1=0.7391 | threshold=0.35 | epoch_selection_score=0.7376 | val_weighted_f1=0.7272
# Epoch 09 | train_loss=0.1495 | val_loss=0.8097 | val_macro_f1=0.5732 | val_creation_f1=0.7500 | val_collapse_f1=0.7473 | threshold=0.35 | epoch_selection_score=0.7488 | val_weighted_f1=0.7384
# Early stopping triggered at epoch 9.
# Selected collapse threshold: 0.35
# Predicted test label counts: {0: 603, 1: 323, 2: 157}
# Test confusion matrix:
# [[569 276 142]
#  [  0  44  10]
#  [ 34   3   5]]
#
# --- ETH | lookback=21 ---
# Train sequences: (1107, 21, 42)
# Val sequences  : (194, 21, 42)
# Test sequences : (1076, 21, 42)
# Train label counts: {0: 904, 1: 187, 2: 16}
# Val label counts  : {0: 4, 1: 115, 2: 75}
# Test label counts : {0: 982, 1: 54, 2: 40}
# Oversampled collapse class with multiplier=4. New train counts: {0: 904, 1: 187, 2: 64}
# Using class weights: [1.  1.3 6.8]
# Epoch 01 | train_loss=0.9930 | val_loss=1.1964 | val_macro_f1=0.1859 | val_creation_f1=0.0000 | val_collapse_f1=0.5576 | threshold=0.10 | epoch_selection_score=0.2509 | val_weighted_f1=0.2156
# Epoch 02 | train_loss=0.8435 | val_loss=1.1873 | val_macro_f1=0.1866 | val_creation_f1=0.0000 | val_collapse_f1=0.5597 | threshold=0.20 | epoch_selection_score=0.2519 | val_weighted_f1=0.2164
# Epoch 03 | train_loss=0.5682 | val_loss=1.1692 | val_macro_f1=0.2433 | val_creation_f1=0.0992 | val_collapse_f1=0.5355 | threshold=0.35 | epoch_selection_score=0.2955 | val_weighted_f1=0.2678
# Epoch 04 | train_loss=0.3596 | val_loss=1.1893 | val_macro_f1=0.4810 | val_creation_f1=0.6391 | val_collapse_f1=0.6585 | threshold=0.35 | epoch_selection_score=0.6478 | val_weighted_f1=0.6364
# Epoch 05 | train_loss=0.2535 | val_loss=1.1722 | val_macro_f1=0.5262 | val_creation_f1=0.7293 | val_collapse_f1=0.6923 | threshold=0.35 | epoch_selection_score=0.7126 | val_weighted_f1=0.7032
# Epoch 06 | train_loss=0.1909 | val_loss=1.1667 | val_macro_f1=0.5665 | val_creation_f1=0.7958 | val_collapse_f1=0.7333 | threshold=0.35 | epoch_selection_score=0.7677 | val_weighted_f1=0.7588
# Epoch 07 | train_loss=0.1633 | val_loss=1.1117 | val_macro_f1=0.5736 | val_creation_f1=0.8021 | val_collapse_f1=0.7368 | threshold=0.35 | epoch_selection_score=0.7727 | val_weighted_f1=0.7641
# Epoch 08 | train_loss=0.1286 | val_loss=1.0794 | val_macro_f1=0.5810 | val_creation_f1=0.8144 | val_collapse_f1=0.7467 | threshold=0.35 | epoch_selection_score=0.7839 | val_weighted_f1=0.7752
# Epoch 09 | train_loss=0.1038 | val_loss=1.0302 | val_macro_f1=0.5894 | val_creation_f1=0.8144 | val_collapse_f1=0.7632 | threshold=0.35 | epoch_selection_score=0.7914 | val_weighted_f1=0.7817
# Epoch 10 | train_loss=0.0949 | val_loss=1.0150 | val_macro_f1=0.5931 | val_creation_f1=0.8205 | val_collapse_f1=0.7682 | threshold=0.35 | epoch_selection_score=0.7970 | val_weighted_f1=0.7873
# Epoch 11 | train_loss=0.0932 | val_loss=1.0150 | val_macro_f1=0.5936 | val_creation_f1=0.8144 | val_collapse_f1=0.7662 | threshold=0.30 | epoch_selection_score=0.7927 | val_weighted_f1=0.7831
# Epoch 12 | train_loss=0.0840 | val_loss=1.0333 | val_macro_f1=0.5973 | val_creation_f1=0.8205 | val_collapse_f1=0.7763 | threshold=0.30 | epoch_selection_score=0.8006 | val_weighted_f1=0.7905
# Epoch 13 | train_loss=0.0775 | val_loss=1.0305 | val_macro_f1=0.5973 | val_creation_f1=0.8205 | val_collapse_f1=0.7763 | threshold=0.35 | epoch_selection_score=0.8006 | val_weighted_f1=0.7905
# Epoch 14 | train_loss=0.0672 | val_loss=1.0031 | val_macro_f1=0.6009 | val_creation_f1=0.8265 | val_collapse_f1=0.7763 | threshold=0.35 | epoch_selection_score=0.8039 | val_weighted_f1=0.7942
# Epoch 15 | train_loss=0.0716 | val_loss=1.0183 | val_macro_f1=0.6009 | val_creation_f1=0.8265 | val_collapse_f1=0.7763 | threshold=0.35 | epoch_selection_score=0.8039 | val_weighted_f1=0.7942
# Selected collapse threshold: 0.35
# Predicted test label counts: {0: 484, 1: 351, 2: 241}
# Test confusion matrix:
# [[451 308 223]
#  [  0  43  11]
#  [ 33   0   7]]
#
# --- ETH | lookback=30 ---
# Train sequences: (1098, 30, 42)
# Val sequences  : (185, 30, 42)
# Test sequences : (1067, 30, 42)
# Train label counts: {0: 895, 1: 187, 2: 16}
# Val label counts  : {0: 4, 1: 115, 2: 66}
# Test label counts : {0: 974, 1: 54, 2: 39}
# Oversampled collapse class with multiplier=4. New train counts: {0: 895, 1: 187, 2: 64}
# Using class weights: [1.  1.3 6.8]
# Epoch 01 | train_loss=0.9631 | val_loss=1.2241 | val_macro_f1=0.2198 | val_creation_f1=0.0000 | val_collapse_f1=0.5926 | threshold=0.30 | epoch_selection_score=0.2667 | val_weighted_f1=0.2129
# Epoch 02 | train_loss=0.8047 | val_loss=1.1819 | val_macro_f1=0.2287 | val_creation_f1=0.0000 | val_collapse_f1=0.6093 | threshold=0.30 | epoch_selection_score=0.2742 | val_weighted_f1=0.2190
# Epoch 03 | train_loss=0.5460 | val_loss=1.1465 | val_macro_f1=0.2464 | val_creation_f1=0.0000 | val_collapse_f1=0.6623 | threshold=0.30 | epoch_selection_score=0.2980 | val_weighted_f1=0.2379
# Epoch 04 | train_loss=0.3712 | val_loss=1.1665 | val_macro_f1=0.5896 | val_creation_f1=0.8325 | val_collapse_f1=0.7259 | threshold=0.35 | epoch_selection_score=0.7845 | val_weighted_f1=0.7810
# Epoch 05 | train_loss=0.2618 | val_loss=1.1051 | val_macro_f1=0.5986 | val_creation_f1=0.8384 | val_collapse_f1=0.7353 | threshold=0.35 | epoch_selection_score=0.7920 | val_weighted_f1=0.7883
# Epoch 06 | train_loss=0.2061 | val_loss=1.0458 | val_macro_f1=0.6062 | val_creation_f1=0.8500 | val_collapse_f1=0.7463 | threshold=0.35 | epoch_selection_score=0.8033 | val_weighted_f1=0.7994
# Epoch 07 | train_loss=0.1766 | val_loss=1.0344 | val_macro_f1=0.6139 | val_creation_f1=0.8614 | val_collapse_f1=0.7519 | threshold=0.35 | epoch_selection_score=0.8121 | val_weighted_f1=0.8086
# Epoch 08 | train_loss=0.1404 | val_loss=1.0317 | val_macro_f1=0.6291 | val_creation_f1=0.8835 | val_collapse_f1=0.7752 | threshold=0.35 | epoch_selection_score=0.8348 | val_weighted_f1=0.8307
# Epoch 09 | train_loss=0.1304 | val_loss=1.0137 | val_macro_f1=0.6215 | val_creation_f1=0.8725 | val_collapse_f1=0.7634 | threshold=0.35 | epoch_selection_score=0.8234 | val_weighted_f1=0.8197
# Epoch 10 | train_loss=0.1128 | val_loss=1.0136 | val_macro_f1=0.6215 | val_creation_f1=0.8725 | val_collapse_f1=0.7634 | threshold=0.35 | epoch_selection_score=0.8234 | val_weighted_f1=0.8197
# Epoch 11 | train_loss=0.1045 | val_loss=1.0391 | val_macro_f1=0.6291 | val_creation_f1=0.8835 | val_collapse_f1=0.7752 | threshold=0.35 | epoch_selection_score=0.8348 | val_weighted_f1=0.8307
# Epoch 12 | train_loss=0.0982 | val_loss=1.0564 | val_macro_f1=0.6253 | val_creation_f1=0.8780 | val_collapse_f1=0.7692 | threshold=0.35 | epoch_selection_score=0.8291 | val_weighted_f1=0.8252
# Early stopping triggered at epoch 12.
# Selected collapse threshold: 0.35
# Predicted test label counts: {0: 470, 1: 374, 2: 223}
# Test confusion matrix:
# [[437 329 208]
#  [  0  45   9]
#  [ 33   0   6]]
#
# Candidate diagnostics for selected coin:
#   coin         target_col  lookback              selection_mode  threshold  \
# 0  ETH  gsadf_map_90_lead        30  creation_collapse_weighted       0.35
# 1  ETH  gsadf_map_90_lead        21  creation_collapse_weighted       0.35
# 2  ETH  gsadf_map_90_lead        14  creation_collapse_weighted       0.35
#
#    selection_score  val_macro_f1  val_creation_f1  val_collapse_f1  \
# 0         0.834760      0.629087         0.883495         0.775194
# 1         0.803934      0.600949         0.826531         0.776316
# 2         0.768590      0.560835         0.820513         0.705128
#
#    val_collapse_recall  test_macro_f1  test_creation_f1  test_collapse_f1  \
# 0             0.757576       0.287115          0.210280          0.045802
# 1             0.786667       0.292482          0.212346          0.049822
# 2             0.670732       0.333132          0.233422          0.050251
#
#    test_collapse_recall  train_collapse_n  val_collapse_n  test_collapse_n  \
# 0              0.153846                16              66               39
# 1              0.175000                16              75               40
# 2              0.119048                16              82               42
#
#    pred_test_collapse_n
# 0                   223
# 1                   241
# 2                   157
# ======================================================================
# Coin: SOL
# ======================================================================
# Split info: {'train_start': '2020-08-11', 'train_end': '2021-09-30', 'val_start': '2021-10-01', 'val_end': '2022-05-31', 'test_start': '2022-06-01', 'test_end': '2024-12-31', 'split_strategy': 'manual_data_aware', 'coin': 'SOL', 'target_col': 'gsadf_map_90_lead', 'candidate_val_start': '2021-10-01', 'candidate_test_start': '2022-06-01', 'raw_train_counts': {0: 335, 1: 60, 2: 21}, 'raw_val_counts': {0: 148, 1: 50, 2: 45}, 'raw_test_counts': {0: 654, 1: 180, 2: 111}, 'collapse_benchmark_eligible': True}
# Selection mode: creation_collapse_weighted
# Lookbacks for this coin: [7, 14, 21]
# Target: gsadf_map_90_lead
# Collapse benchmark eligible: True
#
# --- SOL | lookback=7 ---
# Train sequences: (410, 7, 42)
# Val sequences  : (237, 7, 42)
# Test sequences : (939, 7, 42)
# Train label counts: {0: 329, 1: 60, 2: 21}
# Val label counts  : {0: 148, 1: 46, 2: 43}
# Test label counts : {0: 654, 1: 180, 2: 105}
# Oversampled collapse class with multiplier=3. New train counts: {0: 329, 1: 60, 2: 63}
# Using class weights: [1.  1.2 1.6]
# Epoch 01 | train_loss=1.0732 | val_loss=1.0927 | val_macro_f1=0.3411 | val_creation_f1=0.3019 | val_collapse_f1=0.0000 | threshold=0.30 | epoch_selection_score=0.1660 | val_weighted_f1=0.5090
# Epoch 02 | train_loss=1.0294 | val_loss=1.0832 | val_macro_f1=0.1024 | val_creation_f1=0.0000 | val_collapse_f1=0.3071 | threshold=0.10 | epoch_selection_score=0.1382 | val_weighted_f1=0.0557
# Epoch 03 | train_loss=0.9794 | val_loss=1.0757 | val_macro_f1=0.1024 | val_creation_f1=0.0000 | val_collapse_f1=0.3071 | threshold=0.10 | epoch_selection_score=0.1382 | val_weighted_f1=0.0557
# Epoch 04 | train_loss=0.8849 | val_loss=1.0652 | val_macro_f1=0.1072 | val_creation_f1=0.0000 | val_collapse_f1=0.3082 | threshold=0.25 | epoch_selection_score=0.1387 | val_weighted_f1=0.0643
# Epoch 05 | train_loss=0.7804 | val_loss=1.0535 | val_macro_f1=0.1024 | val_creation_f1=0.0000 | val_collapse_f1=0.3071 | threshold=0.10 | epoch_selection_score=0.1382 | val_weighted_f1=0.0557
# Early stopping triggered at epoch 5.
# Selected collapse threshold: 0.3
# Predicted test label counts: {0: 623, 1: 255, 2: 61}
# Test confusion matrix:
# [[402 202  50]
#  [131  38  11]
#  [ 90  15   0]]
#
# --- SOL | lookback=14 ---
# Train sequences: (403, 14, 42)
# Val sequences  : (230, 14, 42)
# Test sequences : (932, 14, 42)
# Train label counts: {0: 322, 1: 60, 2: 21}
# Val label counts  : {0: 148, 1: 46, 2: 36}
# Test label counts : {0: 654, 1: 180, 2: 98}
# Oversampled collapse class with multiplier=3. New train counts: {0: 322, 1: 60, 2: 63}
# Using class weights: [1.  1.2 1.6]
# Epoch 01 | train_loss=1.0810 | val_loss=1.0764 | val_macro_f1=0.0902 | val_creation_f1=0.0000 | val_collapse_f1=0.2707 | threshold=0.10 | epoch_selection_score=0.1218 | val_weighted_f1=0.0424
# Epoch 02 | train_loss=1.0269 | val_loss=1.0627 | val_macro_f1=0.0902 | val_creation_f1=0.0000 | val_collapse_f1=0.2707 | threshold=0.10 | epoch_selection_score=0.1218 | val_weighted_f1=0.0424
# Epoch 03 | train_loss=0.9635 | val_loss=1.0498 | val_macro_f1=0.1058 | val_creation_f1=0.0000 | val_collapse_f1=0.2791 | threshold=0.30 | epoch_selection_score=0.1256 | val_weighted_f1=0.0684
# Epoch 04 | train_loss=0.8755 | val_loss=1.0379 | val_macro_f1=0.1317 | val_creation_f1=0.0000 | val_collapse_f1=0.3051 | threshold=0.30 | epoch_selection_score=0.1373 | val_weighted_f1=0.1056
# Epoch 05 | train_loss=0.7789 | val_loss=1.0288 | val_macro_f1=0.1390 | val_creation_f1=0.0000 | val_collapse_f1=0.3111 | threshold=0.30 | epoch_selection_score=0.1400 | val_weighted_f1=0.1168
# Epoch 06 | train_loss=0.6793 | val_loss=1.0281 | val_macro_f1=0.1395 | val_creation_f1=0.0000 | val_collapse_f1=0.3139 | threshold=0.30 | epoch_selection_score=0.1413 | val_weighted_f1=0.1165
# Epoch 07 | train_loss=0.5682 | val_loss=1.0361 | val_macro_f1=0.1310 | val_creation_f1=0.0000 | val_collapse_f1=0.3070 | threshold=0.25 | epoch_selection_score=0.1382 | val_weighted_f1=0.1034
# Epoch 08 | train_loss=0.4842 | val_loss=1.0477 | val_macro_f1=0.1245 | val_creation_f1=0.0000 | val_collapse_f1=0.2982 | threshold=0.25 | epoch_selection_score=0.1342 | val_weighted_f1=0.0951
# Epoch 09 | train_loss=0.4139 | val_loss=1.0666 | val_macro_f1=0.1386 | val_creation_f1=0.0000 | val_collapse_f1=0.2818 | threshold=0.25 | epoch_selection_score=0.1268 | val_weighted_f1=0.1304
# Epoch 10 | train_loss=0.3376 | val_loss=1.0955 | val_macro_f1=0.1153 | val_creation_f1=0.0000 | val_collapse_f1=0.2645 | threshold=0.15 | epoch_selection_score=0.1190 | val_weighted_f1=0.0938
# Early stopping triggered at epoch 10.
# Selected collapse threshold: 0.3
# Predicted test label counts: {0: 239, 1: 0, 2: 693}
# Test confusion matrix:
# [[126   0 528]
#  [113   0  67]
#  [  0   0  98]]
#
# --- SOL | lookback=21 ---
# Train sequences: (396, 21, 42)
# Val sequences  : (223, 21, 42)
# Test sequences : (925, 21, 42)
# Train label counts: {0: 315, 1: 60, 2: 21}
# Val label counts  : {0: 148, 1: 40, 2: 35}
# Test label counts : {0: 654, 1: 180, 2: 91}
# Oversampled collapse class with multiplier=3. New train counts: {0: 315, 1: 60, 2: 63}
# Using class weights: [1.  1.2 1.6]
# Epoch 01 | train_loss=1.1698 | val_loss=1.1369 | val_macro_f1=0.0904 | val_creation_f1=0.0000 | val_collapse_f1=0.2713 | threshold=0.10 | epoch_selection_score=0.1221 | val_weighted_f1=0.0426
# Epoch 02 | train_loss=1.1195 | val_loss=1.1116 | val_macro_f1=0.0904 | val_creation_f1=0.0000 | val_collapse_f1=0.2713 | threshold=0.10 | epoch_selection_score=0.1221 | val_weighted_f1=0.0426
# Epoch 03 | train_loss=1.0514 | val_loss=1.0807 | val_macro_f1=0.1091 | val_creation_f1=0.0417 | val_collapse_f1=0.2857 | threshold=0.30 | epoch_selection_score=0.1515 | val_weighted_f1=0.0523
# Epoch 04 | train_loss=0.9515 | val_loss=1.0532 | val_macro_f1=0.1223 | val_creation_f1=0.0000 | val_collapse_f1=0.3226 | threshold=0.30 | epoch_selection_score=0.1452 | val_weighted_f1=0.0801
# Epoch 05 | train_loss=0.8335 | val_loss=1.0176 | val_macro_f1=0.1420 | val_creation_f1=0.0000 | val_collapse_f1=0.3286 | threshold=0.30 | epoch_selection_score=0.1479 | val_weighted_f1=0.1162
# Epoch 06 | train_loss=0.6974 | val_loss=0.9910 | val_macro_f1=0.1725 | val_creation_f1=0.0000 | val_collapse_f1=0.3431 | threshold=0.30 | epoch_selection_score=0.1544 | val_weighted_f1=0.1696
# Epoch 07 | train_loss=0.5644 | val_loss=0.9703 | val_macro_f1=0.2033 | val_creation_f1=0.0000 | val_collapse_f1=0.3723 | threshold=0.30 | epoch_selection_score=0.1676 | val_weighted_f1=0.2161
# Epoch 08 | train_loss=0.4625 | val_loss=0.9536 | val_macro_f1=0.2814 | val_creation_f1=0.0667 | val_collapse_f1=0.3902 | threshold=0.30 | epoch_selection_score=0.2123 | val_weighted_f1=0.3303
# Epoch 09 | train_loss=0.3777 | val_loss=0.9453 | val_macro_f1=0.4602 | val_creation_f1=0.5063 | val_collapse_f1=0.4076 | threshold=0.30 | epoch_selection_score=0.4619 | val_weighted_f1=0.4645
# Epoch 10 | train_loss=0.3262 | val_loss=0.9331 | val_macro_f1=0.4373 | val_creation_f1=0.6207 | val_collapse_f1=0.3265 | threshold=0.25 | epoch_selection_score=0.4883 | val_weighted_f1=0.4045
# Epoch 11 | train_loss=0.2971 | val_loss=0.9195 | val_macro_f1=0.4546 | val_creation_f1=0.6452 | val_collapse_f1=0.3333 | threshold=0.25 | epoch_selection_score=0.5048 | val_weighted_f1=0.4238
# Epoch 12 | train_loss=0.2764 | val_loss=0.9074 | val_macro_f1=0.4901 | val_creation_f1=0.7042 | val_collapse_f1=0.3516 | threshold=0.25 | epoch_selection_score=0.5456 | val_weighted_f1=0.4566
# Epoch 13 | train_loss=0.2477 | val_loss=0.9067 | val_macro_f1=0.4859 | val_creation_f1=0.6582 | val_collapse_f1=0.3550 | threshold=0.25 | epoch_selection_score=0.5218 | val_weighted_f1=0.4688
# Epoch 14 | train_loss=0.2574 | val_loss=0.9069 | val_macro_f1=0.4861 | val_creation_f1=0.6667 | val_collapse_f1=0.3494 | threshold=0.25 | epoch_selection_score=0.5239 | val_weighted_f1=0.4679
# Epoch 15 | train_loss=0.2164 | val_loss=0.9284 | val_macro_f1=0.4948 | val_creation_f1=0.7097 | val_collapse_f1=0.3169 | threshold=0.20 | epoch_selection_score=0.5329 | val_weighted_f1=0.4808
# Selected collapse threshold: 0.25
# Predicted test label counts: {0: 191, 1: 135, 2: 599}
# Test confusion matrix:
# [[153  57 444]
#  [ 27  78  75]
#  [ 11   0  80]]
#
# Candidate diagnostics for selected coin:
#   coin         target_col  lookback              selection_mode  threshold  \
# 0  SOL  gsadf_map_90_lead        21  creation_collapse_weighted       0.25
# 1  SOL  gsadf_map_90_lead         7  creation_collapse_weighted       0.30
# 2  SOL  gsadf_map_90_lead        14  creation_collapse_weighted       0.30
#
#    selection_score  val_macro_f1  val_creation_f1  val_collapse_f1  \
# 0         0.545566      0.490127         0.704225         0.351648
# 1         0.166038      0.341066         0.301887         0.000000
# 2         0.141256      0.139538         0.000000         0.313901
#
#    val_collapse_recall  test_macro_f1  test_creation_f1  test_collapse_f1  \
# 0             0.914286       0.363084          0.495238          0.231884
# 1             0.000000       0.268104          0.174713          0.000000
# 2             0.972222       0.176661          0.000000          0.247788
#
#    test_collapse_recall  train_collapse_n  val_collapse_n  test_collapse_n  \
# 0              0.879121                21              35               91
# 1              0.000000                21              43              105
# 2              1.000000                21              36               98
#
#    pred_test_collapse_n
# 0                   599
# 1                    61
# 2                   693

# %% [markdown]
# ## 14. Summarise Results
#
# Build the final analysis tables across coins.

# %%
# Collect summary tables across coins
summary_rows = []
candidate_tables = []

for result in all_results:
    y_true = result["y_test"]
    y_pred = result["y_pred"]

    precision_pc = precision_score(y_true, y_pred, average=None, labels=LABELS, zero_division=0)
    recall_pc = recall_score(y_true, y_pred, average=None, labels=LABELS, zero_division=0)
    f1_pc = f1_score(y_true, y_pred, average=None, labels=LABELS, zero_division=0)

    row = {
        "Coin": result["coin"],
        "Target": result["target_col"],
        "Benchmark Flag": result["benchmark_flag"],
        "Lookback": result["lookback"],
        "Selection Mode": result["selection_mode"],
        "Selection Score": round(float(result["candidate_row"]["selection_score"]), 4),
        "Selected Threshold": round(float(result.get("selected_threshold", DEFAULT_FIXED_COLLAPSE_THRESHOLD)), 3),
        "Val Macro F1": round(float(result["val_macro_f1"]), 4),
        "Test Macro F1": round(float(result["test_macro_f1"]), 4),
        "Test Weighted F1": round(float(result["test_weighted_f1"]), 4),
        "Train Collapse N": int(result["train_counts"].get(COLLAPSE_CLASS, 0)),
        "Val Collapse N": int(result["val_counts"].get(COLLAPSE_CLASS, 0)),
        "Test Collapse N": int(result["test_counts"].get(COLLAPSE_CLASS, 0)),
        "Pred Test Collapse N": int(result["pred_test_counts"].get(COLLAPSE_CLASS, 0)),
        "Precision Not Bubble": round(float(precision_pc[0]), 4),
        "Recall Not Bubble": round(float(recall_pc[0]), 4),
        "F1 Not Bubble": round(float(f1_pc[0]), 4),
        "Precision Creation": round(float(precision_pc[1]), 4),
        "Recall Creation": round(float(recall_pc[1]), 4),
        "F1 Creation": round(float(f1_pc[1]), 4),
        "Precision Collapse": round(float(precision_pc[2]), 4),
        "Recall Collapse": round(float(recall_pc[2]), 4),
        "F1 Collapse": round(float(f1_pc[2]), 4),
        "Interpretation Status": classify_result_status({
            "Coin": result["coin"],
            "Test Collapse N": int(result["test_counts"].get(COLLAPSE_CLASS, 0)),
            "F1 Collapse": float(f1_pc[2]),
            "F1 Creation": float(f1_pc[1]),
        }),
    }
    summary_rows.append(row)

    diagnostics = result["candidate_table"].copy()
    diagnostics["selected_lookback"] = result["lookback"]
    diagnostics["selected_threshold"] = round(float(result.get("selected_threshold", DEFAULT_FIXED_COLLAPSE_THRESHOLD)), 3)
    diagnostics["target_col"] = result["target_col"]
    candidate_tables.append(diagnostics)

summary_df = pd.DataFrame(summary_rows).sort_values("Coin").reset_index(drop=True)
display(summary_df)
summary_df.to_csv(OUTPUT_DIR / f"lstm_summary_metrics_{TARGET_COL}.csv", index=False)

collapse_benchmark_df = (
    summary_df[~summary_df["Coin"].isin(COLLAPSE_BENCHMARK_EXCLUDE)]
    .sort_values("Coin")
    .reset_index(drop=True)
)
display(collapse_benchmark_df)
collapse_benchmark_df.to_csv(
    OUTPUT_DIR / f"lstm_summary_metrics_{TARGET_COL}_collapse_benchmark_only.csv",
    index=False,
)

all_candidate_diagnostics_df = (
    pd.concat(candidate_tables, ignore_index=True)
    if candidate_tables else pd.DataFrame()
)

if not all_candidate_diagnostics_df.empty:
    display(all_candidate_diagnostics_df)
    all_candidate_diagnostics_df.to_csv(
        OUTPUT_DIR / f"all_candidate_diagnostics_{TARGET_COL}.csv",
        index=False
    )
# Out:
#    Coin             Target  Benchmark Flag  Lookback  \
# 0   ADA  gsadf_map_90_lead           False        21
# 1   BNB  gsadf_map_90_lead            True        21
# 2   BTC  gsadf_map_90_lead            True        30
# 3  DOGE  gsadf_map_90_lead           False        14
# 4   ETH  gsadf_map_90_lead            True        30
# 5   SOL  gsadf_map_90_lead            True        21
#
#                Selection Mode  Selection Score  Selected Threshold  \
# 0               creation_only           0.9398                0.35
# 1  creation_collapse_weighted           0.3547                0.30
# 2  creation_collapse_weighted           0.7751                0.25
# 3               creation_only           0.9434                0.25
# 4  creation_collapse_weighted           0.8348                0.35
# 5  creation_collapse_weighted           0.5456                0.25
#
#    Val Macro F1  Test Macro F1  Test Weighted F1  ...  Precision Not Bubble  \
# 0        0.5773         0.7005            0.8610  ...                0.9794
# 1        0.2627         0.2428            0.5553  ...                0.7997
# 2        0.7983         0.5291            0.7443  ...                0.9574
# 3        0.4414         0.5480            0.8607  ...                0.9662
# 4        0.6291         0.2871            0.5648  ...                0.9298
# 5        0.4901         0.3631            0.3752  ...                0.8010
#
#    Recall Not Bubble  F1 Not Bubble  Precision Creation  Recall Creation  \
# 0             0.8307         0.8989              0.3417           0.9762
# 1             0.5328         0.6395              0.0000           0.0000
# 2             0.6838         0.7978              0.5842           0.7195
# 3             0.8466         0.9025              0.4525           0.8438
# 4             0.4487         0.6053              0.1203           0.8333
# 5             0.2339         0.3621              0.5778           0.4333
#
#    F1 Creation  Precision Collapse  Recall Collapse  F1 Collapse  \
# 0       0.5062              0.6964           0.6964       0.6964
# 1       0.0000              0.0481           0.5789       0.0889
# 2       0.6448              0.0863           0.4490       0.1447
# 3       0.5891              0.1026           0.2963       0.1524
# 4       0.2103              0.0269           0.1538       0.0458
# 5       0.4952              0.1336           0.8791       0.2319
#
#    Interpretation Status
# 0        collapse_usable
# 1          collapse_weak
# 2          collapse_weak
# 3          collapse_weak
# 4          collapse_weak
# 5        collapse_usable
#
# [6 rows x 24 columns]
#   Coin             Target  Benchmark Flag  Lookback  \
# 0  BNB  gsadf_map_90_lead            True        21
# 1  BTC  gsadf_map_90_lead            True        30
# 2  ETH  gsadf_map_90_lead            True        30
# 3  SOL  gsadf_map_90_lead            True        21
#
#                Selection Mode  Selection Score  Selected Threshold  \
# 0  creation_collapse_weighted           0.3547                0.30
# 1  creation_collapse_weighted           0.7751                0.25
# 2  creation_collapse_weighted           0.8348                0.35
# 3  creation_collapse_weighted           0.5456                0.25
#
#    Val Macro F1  Test Macro F1  Test Weighted F1  ...  Precision Not Bubble  \
# 0        0.2627         0.2428            0.5553  ...                0.7997
# 1        0.7983         0.5291            0.7443  ...                0.9574
# 2        0.6291         0.2871            0.5648  ...                0.9298
# 3        0.4901         0.3631            0.3752  ...                0.8010
#
#    Recall Not Bubble  F1 Not Bubble  Precision Creation  Recall Creation  \
# 0             0.5328         0.6395              0.0000           0.0000
# 1             0.6838         0.7978              0.5842           0.7195
# 2             0.4487         0.6053              0.1203           0.8333
# 3             0.2339         0.3621              0.5778           0.4333
#
#    F1 Creation  Precision Collapse  Recall Collapse  F1 Collapse  \
# 0       0.0000              0.0481           0.5789       0.0889
# 1       0.6448              0.0863           0.4490       0.1447
# 2       0.2103              0.0269           0.1538       0.0458
# 3       0.4952              0.1336           0.8791       0.2319
#
#    Interpretation Status
# 0          collapse_weak
# 1          collapse_weak
# 2          collapse_weak
# 3        collapse_usable
#
# [4 rows x 24 columns]
#     coin         target_col  lookback              selection_mode  threshold  \
# 0    ADA  gsadf_map_90_lead        21               creation_only       0.35
# 1    ADA  gsadf_map_90_lead        14               creation_only       0.20
# 2    BNB  gsadf_map_90_lead        21  creation_collapse_weighted       0.30
# 3    BNB  gsadf_map_90_lead        30  creation_collapse_weighted       0.35
# 4    BNB  gsadf_map_90_lead        14  creation_collapse_weighted       0.35
# 5    BTC  gsadf_map_90_lead        30  creation_collapse_weighted       0.25
# 6    BTC  gsadf_map_90_lead        14  creation_collapse_weighted       0.25
# 7    BTC  gsadf_map_90_lead        21  creation_collapse_weighted       0.25
# 8   DOGE  gsadf_map_90_lead        14               creation_only       0.25
# 9   DOGE  gsadf_map_90_lead        21               creation_only       0.30
# 10   ETH  gsadf_map_90_lead        30  creation_collapse_weighted       0.35
# 11   ETH  gsadf_map_90_lead        21  creation_collapse_weighted       0.35
# 12   ETH  gsadf_map_90_lead        14  creation_collapse_weighted       0.35
# 13   SOL  gsadf_map_90_lead        21  creation_collapse_weighted       0.25
# 14   SOL  gsadf_map_90_lead         7  creation_collapse_weighted       0.30
# 15   SOL  gsadf_map_90_lead        14  creation_collapse_weighted       0.30
#
#     selection_score  val_macro_f1  val_creation_f1  val_collapse_f1  \
# 0          0.939759      0.577279         0.939759         0.792079
# 1          0.926829      0.537515         0.926829         0.685714
# 2          0.354680      0.262726         0.000000         0.788177
# 3          0.318072      0.235609         0.000000         0.706827
# 4          0.306761      0.206695         0.277228         0.342857
# 5          0.775087      0.798333         0.821429         0.718447
# 6          0.708421      0.749492         0.800000         0.596491
# 7          0.648690      0.696039         0.804124         0.458716
# 8          0.943396      0.441450         0.943396         0.380952
# 9          0.787879      0.534556         0.787879         0.815789
# 10         0.834760      0.629087         0.883495         0.775194
# 11         0.803934      0.600949         0.826531         0.776316
# 12         0.768590      0.560835         0.820513         0.705128
# 13         0.545566      0.490127         0.704225         0.351648
# 14         0.166038      0.341066         0.301887         0.000000
# 15         0.141256      0.139538         0.000000         0.313901
#
#     val_collapse_recall  test_macro_f1  test_creation_f1  test_collapse_f1  \
# 0              0.689655       0.700516          0.506173          0.696429
# 1              0.553846       0.612771          0.590038          0.389105
# 2              0.714286       0.242808          0.000000          0.088889
# 3              0.800000       0.083934          0.000000          0.077472
# 4              0.212389       0.301585          0.232258          0.085526
# 5              0.740000       0.529120          0.644809          0.144737
# 6              0.641509       0.512588          0.608414          0.124294
# 7              0.471698       0.520255          0.674877          0.104530
# 8              0.235294       0.547978          0.589091          0.152381
# 9              0.704545       0.468331          0.445070          0.120301
# 10             0.757576       0.287115          0.210280          0.045802
# 11             0.786667       0.292482          0.212346          0.049822
# 12             0.670732       0.333132          0.233422          0.050251
# 13             0.914286       0.363084          0.495238          0.231884
# 14             0.000000       0.268104          0.174713          0.000000
# 15             0.972222       0.176661          0.000000          0.247788
#
#     test_collapse_recall  train_collapse_n  val_collapse_n  test_collapse_n  \
# 0               0.696429                11              58               56
# 1               0.819672                11              65               61
# 2               0.578947                20             112               38
# 3               1.000000                20             110               38
# 4               0.295455                20             113               44
# 5               0.448980                19              50               49
# 6               0.440000                19              53               50
# 7               0.300000                19              53               50
# 8               0.296296                19              51               27
# 9               0.363636                19              44               22
# 10              0.153846                16              66               39
# 11              0.175000                16              75               40
# 12              0.119048                16              82               42
# 13              0.879121                21              35               91
# 14              0.000000                21              43              105
# 15              1.000000                21              36               98
#
#     pred_test_collapse_n  selected_lookback  selected_threshold
# 0                     56                 21                0.35
# 1                    196                 21                0.35
# 2                    457                 21                0.30
# 3                    943                 21                0.30
# 4                    260                 21                0.30
# 5                    255                 30                0.25
# 6                    304                 30                0.25
# 7                    237                 30                0.25
# 8                     78                 14                0.25
# 9                    111                 14                0.25
# 10                   223                 30                0.35
# 11                   241                 30                0.35
# 12                   157                 30                0.35
# 13                   599                 21                0.25
# 14                    61                 21                0.25
# 15                   693                 21                0.25

# %% [markdown]
# ## 14B. Diagnostic Views
#
# Show all-coin results and the collapse-focused benchmark view separately.

# %%
if not summary_df.empty:
    diagnostic_view = summary_df[[
        "Coin",
        "Benchmark Flag",
        "Lookback",
        "Selection Mode",
        "Selection Score",
        "Val Collapse N",
        "Test Collapse N",
        "Pred Test Collapse N",
        "Recall Collapse",
        "F1 Collapse",
        "F1 Creation",
        "Test Macro F1",
        "Interpretation Status",
    ]].sort_values("Coin").reset_index(drop=True)

    print("All coins diagnostic view")
    display(diagnostic_view)

    print("Collapse benchmark view only")
    display(
        diagnostic_view[~diagnostic_view["Coin"].isin(COLLAPSE_BENCHMARK_EXCLUDE)]
        .reset_index(drop=True)
    )

    print("Coins where test has collapse but model predicts none:")
    zero_pred_collapse = diagnostic_view[
        (diagnostic_view["Test Collapse N"] > 0) &
        (diagnostic_view["Pred Test Collapse N"] == 0)
    ]
    display(zero_pred_collapse if not zero_pred_collapse.empty else pd.DataFrame({"message": ["None"]}))

    print("Coins excluded from collapse benchmark:")
    display(summary_df[summary_df["Coin"].isin(COLLAPSE_BENCHMARK_EXCLUDE)][[
        "Coin", "Test Collapse N", "F1 Collapse", "Interpretation Status"
    ]].reset_index(drop=True))
# Out:
# All coins diagnostic view
#    Coin  Benchmark Flag  Lookback              Selection Mode  \
# 0   ADA           False        21               creation_only
# 1   BNB            True        21  creation_collapse_weighted
# 2   BTC            True        30  creation_collapse_weighted
# 3  DOGE           False        14               creation_only
# 4   ETH            True        30  creation_collapse_weighted
# 5   SOL            True        21  creation_collapse_weighted
#
#    Selection Score  Val Collapse N  Test Collapse N  Pred Test Collapse N  \
# 0           0.9398              58               56                    56
# 1           0.3547             112               38                   457
# 2           0.7751              50               49                   255
# 3           0.9434              51               27                    78
# 4           0.8348              66               39                   223
# 5           0.5456              35               91                   599
#
#    Recall Collapse  F1 Collapse  F1 Creation  Test Macro F1  \
# 0           0.6964       0.6964       0.5062         0.7005
# 1           0.5789       0.0889       0.0000         0.2428
# 2           0.4490       0.1447       0.6448         0.5291
# 3           0.2963       0.1524       0.5891         0.5480
# 4           0.1538       0.0458       0.2103         0.2871
# 5           0.8791       0.2319       0.4952         0.3631
#
#   Interpretation Status
# 0       collapse_usable
# 1         collapse_weak
# 2         collapse_weak
# 3         collapse_weak
# 4         collapse_weak
# 5       collapse_usable
# Collapse benchmark view only
#   Coin  Benchmark Flag  Lookback              Selection Mode  Selection Score  \
# 0  BNB            True        21  creation_collapse_weighted           0.3547
# 1  BTC            True        30  creation_collapse_weighted           0.7751
# 2  ETH            True        30  creation_collapse_weighted           0.8348
# 3  SOL            True        21  creation_collapse_weighted           0.5456
#
#    Val Collapse N  Test Collapse N  Pred Test Collapse N  Recall Collapse  \
# 0             112               38                   457           0.5789
# 1              50               49                   255           0.4490
# 2              66               39                   223           0.1538
# 3              35               91                   599           0.8791
#
#    F1 Collapse  F1 Creation  Test Macro F1 Interpretation Status
# 0       0.0889       0.0000         0.2428         collapse_weak
# 1       0.1447       0.6448         0.5291         collapse_weak
# 2       0.0458       0.2103         0.2871         collapse_weak
# 3       0.2319       0.4952         0.3631       collapse_usable
# Coins where test has collapse but model predicts none:
#   message
# 0    None
# Coins excluded from collapse benchmark:
#    Coin  Test Collapse N  F1 Collapse Interpretation Status
# 0   ADA               56       0.6964       collapse_usable
# 1  DOGE               27       0.1524         collapse_weak

# %% [markdown]
# ## 15. Confusion Matrices
#
# Plot test-set confusion matrices for the selected model of each coin.

# %%
def plot_confusion_matrix_for_result(result):
    cm = confusion_matrix(result["y_test"], result["y_pred"], labels=LABELS)
    plt.figure(figsize=(5.4, 4.4))
    sns.heatmap(
        cm,
        annot=True,
        fmt="d",
        cmap="Blues",
        xticklabels=CLASS_NAMES,
        yticklabels=CLASS_NAMES,
    )
    plt.title(f"{result['coin']} | LSTM | lookback={result['lookback']}")
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.tight_layout()
    plt.show()

for result in all_results:
    plot_confusion_matrix_for_result(result)

# %% [markdown]
# ## 16. Heatmaps
#
# Visual analysis of key metrics across coins.

# %%
if not summary_df.empty:
    heatmap_df_all = summary_df.set_index("Coin")[["F1 Not Bubble", "F1 Creation", "F1 Collapse"]]
    plt.figure(figsize=(7, max(3, len(heatmap_df_all) * 0.7)))
    sns.heatmap(heatmap_df_all, annot=True, fmt=".2f", cmap="YlGnBu")
    plt.title(f"LSTM per-class F1 by coin ({TARGET_COL}, all coins)")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 17. Training Curves
#
# Plot loss and metric curves for the selected run of each coin.

# %%
def plot_history(history_df, title):
    if history_df.empty:
        return
    fig, axes = plt.subplots(1, 2, figsize=(10, 3.6))
    axes[0].plot(history_df["epoch"], history_df["train_loss"], label="train_loss")
    axes[0].plot(history_df["epoch"], history_df["val_loss"], label="val_loss")
    axes[0].set_title(f"{title} - Loss")
    axes[0].legend()

    axes[1].plot(history_df["epoch"], history_df["val_macro_f1"], label="val_macro_f1")
    axes[1].plot(history_df["epoch"], history_df["val_creation_f1"], label="val_creation_f1")
    axes[1].plot(history_df["epoch"], history_df["val_collapse_f1"], label="val_collapse_f1")
    axes[1].plot(history_df["epoch"], history_df["epoch_selection_score"], label="epoch_selection_score")
    axes[1].set_title(f"{title} - Validation event metrics")
    axes[1].legend()
    plt.tight_layout()
    plt.show()

for result in all_results:
    plot_history(result["history"], f"{result['coin']} | lookback={result['lookback']}")

# %% [markdown]
# ## 18. Interpretation Notes
#
# - This final notebook uses **`gsadf_map_90_lead`** as the benchmark target.
# - Report both **overall performance** and **collapse-specific performance** by coin.
# - Interpret **ADA** and **DOGE** more cautiously if out-of-sample collapse events remain limited.
# - Use the per-class F1 and confusion matrices together when discussing collapse detection.
